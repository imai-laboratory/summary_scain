# %%
# Load results
import os
import pandas as pd
from natsort import natsorted
import warnings
warnings.simplefilter('ignore', FutureWarning)

results = pd.DataFrame()
results_path = "./results/generations/info/"
result_file_list = natsorted(os.listdir(results_path))
for filename in result_file_list:
    df = pd.read_csv(results_path + filename, names = ["filename", "turn", "full_summary", "omitted_summary", "similarity"])
    df['turn']=df['turn']-1
    results = pd.concat([results, df])
    results['index'] = range(1, len(results.index) + 1)
    
print(results)
# Out:
#      filename  turn                                       full_summary  \
# 0     PP1.txt     5  B: 北海道ですか。北海道は海の幸や農産物が豊富で、美味しいご飯がたくさんありますね。私は青...
# 1     PP1.txt     5  B: 北海道ですか。北海道は海の幸や農産物が豊富で、美味しいご飯がたくさんありますね。私は青...
# 2     PP1.txt     5  B: 北海道ですか。北海道は海の幸や農産物が豊富で、美味しいご飯がたくさんありますね。私は青...
# 3     PP1.txt     5  B: 北海道ですか。北海道は海の幸や農産物が豊富で、美味しいご飯がたくさんありますね。私は青...
# 4     PP1.txt     6  A: 北海道は、美味しいものがたくさんありますよ。例えば、新鮮な海産物や北海道産の野菜などが...
# ..        ...   ...                                                ...
# 23  PP150.txt    10  私は鹿児島から引っ越してきたのですが、鹿児島でも近所のお子さんたちに手作りの洋服を作ってあげ...
# 24  PP150.txt    11  B: すごいね！手芸が得意なあなたが作る手作りの洋服は、本当に素晴らしいものだと思うよ。それ...
# 25  PP150.txt    11  B: すごいね！手芸が得意なあなたが作る手作りの洋服は、本当に素晴らしいものだと思うよ。それ...
# 26  PP150.txt    11  B: すごいね！手芸が得意なあなたが作る手作りの洋服は、本当に素晴らしいものだと思うよ。それ...
# 27  PP150.txt    11  B: すごいね！手芸が得意なあなたが作る手作りの洋服は、本当に素晴らしいものだと思うよ。それ...
#
#                                       omitted_summary  similarity  index
# 0   B: 北海道ですか。北海道はご飯の美味しいところが多くて羨ましいです。私は青森県出身で、青森...    0.981612      1
# 1   B: 北海道ですか。北海道はご飯の美味しいところが多くて羨ましいです。私は青森県出身で、山の...    0.982335      2
# 2   B: 北海道ですか。北海道は有名な海産物や農産物が豊富で、美味しいご飯がたくさんありますよね...    0.989883      3
# 3   B: 北海道ですか。北海道は海の幸や農産物が豊富で、美味しいご飯がたくさんありますね。私は青...    0.998785      4
# 4   A: 北海道は、美味しいものがたくさんありますよ。例えば、新鮮な海産物や美味しい牛乳などが有...    0.980916      5
# ..                                                ...         ...    ...
# 23  私は鹿児島から引っ越してきたのですが、鹿児島でも近所の子供たちに手作りの洋服を作ってあげたり...    0.998157   4600
# 24         B: すごいね！手芸が得意なんだから、手作りの商品を作って販売したらいいんじゃない？    0.939959   4601
# 25  B: すごいね！あなたが鹿児島から引っ越してきたときに、近所のお子さんたちに作ったものを商売...    0.900531   4602
# 26  B: すごいね！お子さんに手作りの洋服を着せるのが得意なんだね。それ、いっそのこと手作り洋服...    0.961673   4603
# 27        B: すごいね！手作りの洋服を作るのが得意なんだから、それを商売にしてみたらどうかな？    0.963107   4604
#
# [4604 rows x 6 columns]

# %%
# Cast dtype
results = results.astype({"similarity": float, "turn": int})

# results.info()
print(results)
# Out:
#      filename  turn                                       full_summary  \
# 0     PP1.txt     5  B: 北海道ですか。北海道は海の幸や農産物が豊富で、美味しいご飯がたくさんありますね。私は青...
# 1     PP1.txt     5  B: 北海道ですか。北海道は海の幸や農産物が豊富で、美味しいご飯がたくさんありますね。私は青...
# 2     PP1.txt     5  B: 北海道ですか。北海道は海の幸や農産物が豊富で、美味しいご飯がたくさんありますね。私は青...
# 3     PP1.txt     5  B: 北海道ですか。北海道は海の幸や農産物が豊富で、美味しいご飯がたくさんありますね。私は青...
# 4     PP1.txt     6  A: 北海道は、美味しいものがたくさんありますよ。例えば、新鮮な海産物や北海道産の野菜などが...
# ..        ...   ...                                                ...
# 23  PP150.txt    10  私は鹿児島から引っ越してきたのですが、鹿児島でも近所のお子さんたちに手作りの洋服を作ってあげ...
# 24  PP150.txt    11  B: すごいね！手芸が得意なあなたが作る手作りの洋服は、本当に素晴らしいものだと思うよ。それ...
# 25  PP150.txt    11  B: すごいね！手芸が得意なあなたが作る手作りの洋服は、本当に素晴らしいものだと思うよ。それ...
# 26  PP150.txt    11  B: すごいね！手芸が得意なあなたが作る手作りの洋服は、本当に素晴らしいものだと思うよ。それ...
# 27  PP150.txt    11  B: すごいね！手芸が得意なあなたが作る手作りの洋服は、本当に素晴らしいものだと思うよ。それ...
#
#                                       omitted_summary  similarity  index
# 0   B: 北海道ですか。北海道はご飯の美味しいところが多くて羨ましいです。私は青森県出身で、青森...    0.981612      1
# 1   B: 北海道ですか。北海道はご飯の美味しいところが多くて羨ましいです。私は青森県出身で、山の...    0.982335      2
# 2   B: 北海道ですか。北海道は有名な海産物や農産物が豊富で、美味しいご飯がたくさんありますよね...    0.989883      3
# 3   B: 北海道ですか。北海道は海の幸や農産物が豊富で、美味しいご飯がたくさんありますね。私は青...    0.998785      4
# 4   A: 北海道は、美味しいものがたくさんありますよ。例えば、新鮮な海産物や美味しい牛乳などが有...    0.980916      5
# ..                                                ...         ...    ...
# 23  私は鹿児島から引っ越してきたのですが、鹿児島でも近所の子供たちに手作りの洋服を作ってあげたり...    0.998157   4600
# 24         B: すごいね！手芸が得意なんだから、手作りの商品を作って販売したらいいんじゃない？    0.939959   4601
# 25  B: すごいね！あなたが鹿児島から引っ越してきたときに、近所のお子さんたちに作ったものを商売...    0.900531   4602
# 26  B: すごいね！お子さんに手作りの洋服を着せるのが得意なんだね。それ、いっそのこと手作り洋服...    0.961673   4603
# 27        B: すごいね！手作りの洋服を作るのが得意なんだから、それを商売にしてみたらどうかな？    0.963107   4604
#
# [4604 rows x 6 columns]

# %%
# # Remove duplicates
# results = results.drop_duplicates(subset=["filename", "turn"], keep="first")

# print(results)
# Out:
#      filename  turn                                       full_summary  \
# 0     PP1.txt     5  北海道に住んでいることが羨ましいです。北海道は美味しいご飯がたくさんあるところですから。私は...
# 4     PP1.txt     6  北海道は、美味しいものがたくさんあります。例えば、新鮮な海産物や北海道産の野菜などが有名です...
# 8     PP1.txt     7  東京ですか。東京には有名な観光地や高級なショッピングエリア、繁華街など、魅力的な場所がたくさ...
# 12    PP1.txt     8                   私は田舎で育ったので、東京のような都会はとても魅力的な場所です。
# 16    PP1.txt     9  私も東京はとても魅力的な場所だと思います。お休みの日は何をされていますか？私は写真を撮ること...
# ..        ...   ...                                                ...
# 16  PP114.txt     9  私は遅刻が多いので、それが問題だったみたいです。まあ、ドラッグストアの店員をしていてもあまり...
# 20  PP114.txt    10  私も時間に合わせて動くのが難しいことがあるので、あなたの気持ちがよくわかります。でも、もし実...
# 24  PP114.txt    11  現在、私は友達と一緒にルームシェアをしているので、自分だけで決めることができません。もう少し...
# 28  PP114.txt    12                 B: そうなんですね。どちらにせよ、あなたのことを応援していますよ！
# 32  PP114.txt    13                                         B: ありがとうね！
#
#                                       omitted_summary  similarity  index
# 0   北海道に住んでいることが羨ましいです。北海道はご飯の美味しいところがたくさんあるので、食べ物...    0.996280      1
# 4   私は北海道に住んでいて、北海道には美味しい食べ物がたくさんあります。青森は北海道に近いですよ...    0.951953      5
# 8                 東京ですか。東京は有名な観光地や高層ビルが多く、夜景も美しいですよね。    0.952741      9
# 12               私は田舎で生まれ育ったので、山の近くに住んでいる場所はとても魅力的です。    0.951549     13
# 16  私も東京はとても魅力的な場所だと思います。お休みの日は何をして過ごされていますか？私は写真を...    0.998218     17
# ..                                                ...         ...    ...
# 16  私は遅刻が多いので、それが問題だったみたいです。まあ、ドラッグストアの店員をしていてもあまり...    0.995320   4617
# 20  B: そうだったんですか。私も毎日のスケジュールに合わせて動くのが大変で、辛い思いをしていま...    0.917565   4621
# 24    友達と一緒に住んでいるので、自分だけでは決められないんだよ。もう少しここで頑張ってみようかな。    0.938537   4625
# 28             B: そうなんですね。どちらにせよ、あなたの決断を尊重し、応援していますよ！    0.971237   4629
# 32  A: そうだったんですか。わたしも時間に合わせて動くのに苦労したので、わかります。でも、もし...    0.846535   4633
#
# [1151 rows x 6 columns]

# %%
# Show histogram
import matplotlib.pyplot as plt

plt.rcParams["font.family"] = "Times New Roman"   # 使用するフォント
plt.rcParams["font.size"] = 20                 # 文字の大きさ

# plt.xlim(0.75, 1)
hist = plt.hist(results["similarity"], range=[0.6, 1])
plt.xlabel("Similarity score")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Sort by similarity
results = results.sort_values("similarity")
#results = results.reset_index()

print(results)
# Out:
#     filename  turn                                       full_summary  \
# 19  PP25.txt     9  B: わあ、助かります！私は手先が器用なので、頭皮マッサージをお願いします。ただ、力加減には...
# 28  PP57.txt    12  A: 試してみた結果を教えてね！豚骨ラーメンを1日3食食べて、髪の毛にどんな効果があるか教えてね！
# 20  PP11.txt    10  A: そうなんですよ。宮沢賢治の「銀河鉄道の夜」という本が特におすすめです。物語は少年が銀河...
# 20  PP76.txt    10                  B: なで肩って、しとやかっぽくて良いと思うよ。着物が似合いそう。
# 21  PP76.txt    10                  B: なで肩って、しとやかっぽくて良いと思うよ。着物が似合いそう。
# ..       ...   ...                                                ...
# 26  PP96.txt    11        B: そうですね！私たちはそれぞれの仕事で人々の役に立つことを目指して頑張りましょう！
# 27  PP96.txt    11        B: そうですね！私たちはそれぞれの仕事で人々の役に立つことを目指して頑張りましょう！
# 5   PP10.txt     6  A: それでは総合美容家を目指せそうですね。わたしは体で自慢できるのは虫歯がないことぐらいな...
# 15  PP18.txt     8        A: ですよね、なかなか道は覚えられません。お休みの日なんかは何をされているんですか？
# 22  PP36.txt    10       A: それはすごい！自転車で島根から東北の方まで走るなんて、趣味の範囲を超えているわね！
#
#                                       omitted_summary  similarity  index
# 19  B: わあ、助かります！私は手先が器用なので、雪かきのコツを教えていただけると嬉しいです。た...   -0.017414    784
# 28                   A: ねえねえ！最近さー、また一段と体重が増えちゃったんだよね。    0.812288   1753
# 20  A: 朝起きるのが辛いときは、目覚ましを何個もかけるといいですよ。私は母親にも起こしてもらっ...    0.813490    341
# 20  A: そんな風に言われたのは初めてだなあ。ありがとう！あなたの言葉で私は励まされて元気になっ...    0.818072   2313
# 21      A: そんな風に褒められたのは初めてだなあ。ありがとう！なんだか気持ちが明るくなってきた。    0.826654   2314
# ..                                                ...         ...    ...
# 26        B: そうですね！私たちはそれぞれの仕事で人々の役に立つことを目指して頑張りましょう！    1.000000   2895
# 27        B: そうですね！私たちはそれぞれの仕事で人々の役に立つことを目指して頑張りましょう！    1.000000   2896
# 5   A: それでは総合美容家を目指せそうですね。わたしは体で自慢できるのは虫歯がないことぐらいな...    1.000000    290
# 15        A: ですよね、なかなか道は覚えられません。お休みの日なんかは何をされているんですか？    1.000000    552
# 22       A: それはすごい！自転車で島根から東北の方まで走るなんて、趣味の範囲を超えているわね！    1.000000   1131
#
# [3008 rows x 6 columns]

# %%
# Show top and bottom
def show_row(row):
    with open("./dat/" + row.filename) as f:
        dialogue = [l.rstrip() for l in f.readlines()]
    
    full_dialogue = "\n".join(dialogue[:row.turn + 1])
    print("-----------------")
    print("filename")
    print(row.filename)
    print("full dialogue")
    print(full_dialogue)
    print("full summary")
    print(row.full_summary)
    print("omitted summary")
    print(row.omitted_summary)
    print("similarity") 
    print(row.similarity)
    print("index") 
    print(row.index % 4)
    return

NUM_EXAMPLES = 5
for row in results.head(NUM_EXAMPLES).itertuples():
    show_row(row)

for row in results.tail(NUM_EXAMPLES).itertuples():
    show_row(row)
# Out:
# -----------------
# filename
# PP25.txt
# full dialogue
# A: こんにちは。お元気ですか？
# B: ええ！今は事務の仕事をしながら元気にしています！あなたは？
# A: 私も元気にしていますよ。ただ、薬剤師の仕事がハードなので少し疲れています。
# B: 薬剤師って神経を使いそうですものね。わたしは疲れた時は、趣味のDIYを楽しんだりしています。あなたもちゃんとストレス発散してますか？
# A: そうなんですよね。DIY、できるなんて尊敬します。私は中々ストレス発散できていません。
# B: あら、それはいけないわ。よかったら今度頭皮マッサージしてさしあげましょうか？昔美容師になりたかったので、練習してたんですよ。
# A: それはぜひ、やっていただきたいですね。長野育ちなので雪かきは得意なんですが、どうも最近体力が落ちてきてるので。
# B: 長野の雪はすごそうですね！わたし岐阜に引っ越したばかりなんですが、雪かきが大変だったらどうしようかとヒヤヒヤしてます。いつか雪かきのコツを教えてください！
# A: 岐阜ならお隣の県ですよね。その年によって、ひどく雪が積もりますよ。またコツをお教えしましょう。
# B: わあ、助かります！手先は器用な方なんですが、お手柔らかにお願いしますね！
# full summary
# B: わあ、助かります！私は手先が器用なので、頭皮マッサージをお願いします。ただ、力加減には気をつけてくださいね。
# omitted summary
# B: わあ、助かります！私は手先が器用なので、雪かきのコツを教えていただけると嬉しいです。ただし、初めての経験なので、優しく教えていただけるとありがたいですね！
# similarity
# -0.017414496036464
# index
# 0
# -----------------
# filename
# PP57.txt
# full dialogue
# A: ねえねえ！最近さー、また一段と体重が増えちゃったんだよね。
# B: そうなんだ？わたし自分のことにも他の人のことにも鈍感だからわからなかったよ。
# A: うーん。実は最近、朝昼晩、うどんを食べてるから、そのせいだと思うんだ。
# B: そんなに好きなの！？まあわたしも三食ラーメンでもいいくらいラーメン好きだから気持ちわからなくもないけどさ。
# A: あなたはラーメン派なんだね。わたしのうどん好きは、生まれつきだよ。なにせ、うどんの国、四国で生まれ育ったんだもん！
# B: やっぱり生まれたところと好物って関連するよね。わたしも生まれも今住んでるとこも九州だから！ラーメンは豚骨にかぎる！
# A: ああ、そういうことかあ。豚骨ラーメンって、髪の毛にも良さそうだよね。ツヤツヤになりそうだと思わない？
# B: それはどうかな。髪の毛痛んでるの？
# A: うん。ストレートで、ずっと伸ばしてるんだけど、枝毛が気になっちゃって。
# B: わたしもパーマかけてるから枝毛気になるのすごくわかる！
# A: そうなんだ！じゃあさ、豚骨ラーメンを1日3食食べて、髪の毛に効果があるか試してみてよ！
# B: 多分ないと思うけど試してみる！
# A: 結果を教えてね！
# full summary
# A: 試してみた結果を教えてね！豚骨ラーメンを1日3食食べて、髪の毛にどんな効果があるか教えてね！
# omitted summary
# A: ねえねえ！最近さー、また一段と体重が増えちゃったんだよね。
# similarity
# 0.8122883247178049
# index
# 1
# -----------------
# filename
# PP11.txt
# full dialogue
# A: はじめまして。こんにちは。
# B: こんにちは。わたしはいま高校で陸上部に入ってるんですけど。
# A: 高校生なんですね！私はエステティシャンをしています。
# B: かっこいいですね。実は早起きが苦手で朝練が辛いんですよね。
# A: わかりますよ。私も部活をしていた頃は、早起きが辛かったです。
# B: ですよね。どうやって朝起きしていらっしゃったんですか？
# A: 目覚ましを何個もかけていましたね。母親も起こしてくれましたし。
# B: わたしはおばあちゃんっ子なので、おばあちゃんが起こしてくれるんですが、ソフト過ぎて起きられないんですよね。
# A: なんだか想像できます。ちなみに、好きな作家は宮沢賢治ですが、読書はしますか？
# B: あまり読みませんが、その本は知ってます。ファンタジーですよね。
# A: そうなんですよ。ぜひ読んでみてください。
# full summary
# A: そうなんですよ。宮沢賢治の「銀河鉄道の夜」という本が特におすすめです。物語は少年が銀河鉄道に乗って様々な冒険をするファンタジーです。ぜひ読んでみてください。
# omitted summary
# A: 朝起きるのが辛いときは、目覚ましを何個もかけるといいですよ。私は母親にも起こしてもらっていました。でも、おばあちゃんが起こしてくれるとソフトすぎて起きられないんですよね。それなら、ぜひ読んでみてください。
# similarity
# 0.8134900633975874
# index
# 1
# -----------------
# filename
# PP76.txt
# full dialogue
# A: はあ。わたしなで肩がコンプレックスでさ。あなたはある？コンプレックスとか。
# B: そうだなあ、コンプレックスとまでは言わないけど、子供っぽい顔があんまり好きじゃないよ。
# A: 歳を取らないってことだしむしろ羨ましいけどな！
# B: そうかなあ。でも、化粧品メーカーで、こんなわたしでも大人っぽく見えるメイク用品を開発してるの！
# A: それは素敵ね！同じ悩みを持ってる人もいるでしょうし！わたしは尊敬する松下幸之助に憧れて大手電機メーカーに勤めてるのよ。
# B: へえ、憧れてる人と同じ業界にいくって、よっぽどだよ。なにか電化製品は開発した？
# A: わたしは開発じゃなくて営業なの。あなたはストレス溜まることってない？
# B: ストレスはあんまりないよ。ただ、猫背がちょっと気になるかも。
# A: 猫背は直そうと思えば直せるから大丈夫だよ。わたしのなで肩は直しようがないからさ。
# B: なで肩って、しとやかっぽくて良いと思うよ。着物が似合いそう。
# A: そんな風に言われたのは初めてだなあ。ありがとう！なんだか元気になってきた。
# full summary
# B: なで肩って、しとやかっぽくて良いと思うよ。着物が似合いそう。
# omitted summary
# A: そんな風に言われたのは初めてだなあ。ありがとう！あなたの言葉で私は励まされて元気になってきたよ。
# similarity
# 0.8180720065895879
# index
# 1
# -----------------
# filename
# PP76.txt
# full dialogue
# A: はあ。わたしなで肩がコンプレックスでさ。あなたはある？コンプレックスとか。
# B: そうだなあ、コンプレックスとまでは言わないけど、子供っぽい顔があんまり好きじゃないよ。
# A: 歳を取らないってことだしむしろ羨ましいけどな！
# B: そうかなあ。でも、化粧品メーカーで、こんなわたしでも大人っぽく見えるメイク用品を開発してるの！
# A: それは素敵ね！同じ悩みを持ってる人もいるでしょうし！わたしは尊敬する松下幸之助に憧れて大手電機メーカーに勤めてるのよ。
# B: へえ、憧れてる人と同じ業界にいくって、よっぽどだよ。なにか電化製品は開発した？
# A: わたしは開発じゃなくて営業なの。あなたはストレス溜まることってない？
# B: ストレスはあんまりないよ。ただ、猫背がちょっと気になるかも。
# A: 猫背は直そうと思えば直せるから大丈夫だよ。わたしのなで肩は直しようがないからさ。
# B: なで肩って、しとやかっぽくて良いと思うよ。着物が似合いそう。
# A: そんな風に言われたのは初めてだなあ。ありがとう！なんだか元気になってきた。
# full summary
# B: なで肩って、しとやかっぽくて良いと思うよ。着物が似合いそう。
# omitted summary
# A: そんな風に褒められたのは初めてだなあ。ありがとう！なんだか気持ちが明るくなってきた。
# similarity
# 0.8266543312301422
# index
# 2
# -----------------
# filename
# PP96.txt
# full dialogue
# A: こんにちは。最近はどんなことして過ごしていましたか？
# B: 実は最近会社を興しましてね。探偵業をやってるんです。
# A: 探偵？それは珍しいお仕事を、しかもご自分で興されたなんて！なかなか大変なお仕事じゃありませんか？
# B: ははは。探偵と言っても多い仕事は迷子になったペット探しなんですよ。わたしも犬を飼っているので他人事とは思えなくて。
# A: 犬の気持ちが分かって、すぐに発見してもらえそうで心強いですよ！私もウサギを飼っているのですが、万が一迷子になった時はぜひ一緒に探してください。
# B: はい、お任せください！そういえば、あなたはどんなお仕事をされていましたっけ？
# A: 家政婦を長くやっています。昔から家事が大好きでして。
# B: 家政婦ですか！家政婦というとどうしてもドラマのようなイメージをしてしまいますが、実際はいかがですか？
# A: 家政婦は見た…ですね！探偵気分を味わえそうなんですけど、実際はなかなかそういった機会にはめぐまれません。
# B: そうなんですね！ドラマと現実が違うという点では家政婦も探偵も同じですね。
# A: うふふ、ほんとうに。でも人の役に立てるという意味ではやりがいのある仕事ですし、お互い頑張りましょうね。
# B: そうですね！がんばりましょう！
# full summary
# B: そうですね！私たちはそれぞれの仕事で人々の役に立つことを目指して頑張りましょう！
# omitted summary
# B: そうですね！私たちはそれぞれの仕事で人々の役に立つことを目指して頑張りましょう！
# similarity
# 1.0000000000000002
# index
# 3
# -----------------
# filename
# PP96.txt
# full dialogue
# A: こんにちは。最近はどんなことして過ごしていましたか？
# B: 実は最近会社を興しましてね。探偵業をやってるんです。
# A: 探偵？それは珍しいお仕事を、しかもご自分で興されたなんて！なかなか大変なお仕事じゃありませんか？
# B: ははは。探偵と言っても多い仕事は迷子になったペット探しなんですよ。わたしも犬を飼っているので他人事とは思えなくて。
# A: 犬の気持ちが分かって、すぐに発見してもらえそうで心強いですよ！私もウサギを飼っているのですが、万が一迷子になった時はぜひ一緒に探してください。
# B: はい、お任せください！そういえば、あなたはどんなお仕事をされていましたっけ？
# A: 家政婦を長くやっています。昔から家事が大好きでして。
# B: 家政婦ですか！家政婦というとどうしてもドラマのようなイメージをしてしまいますが、実際はいかがですか？
# A: 家政婦は見た…ですね！探偵気分を味わえそうなんですけど、実際はなかなかそういった機会にはめぐまれません。
# B: そうなんですね！ドラマと現実が違うという点では家政婦も探偵も同じですね。
# A: うふふ、ほんとうに。でも人の役に立てるという意味ではやりがいのある仕事ですし、お互い頑張りましょうね。
# B: そうですね！がんばりましょう！
# full summary
# B: そうですね！私たちはそれぞれの仕事で人々の役に立つことを目指して頑張りましょう！
# omitted summary
# B: そうですね！私たちはそれぞれの仕事で人々の役に立つことを目指して頑張りましょう！
# similarity
# 1.0000000000000002
# index
# 0
# -----------------
# filename
# PP10.txt
# full dialogue
# A: こんにちは。お話して大丈夫ですか？
# B: はい、大丈夫です。今、飼っている熱帯魚の世話をしていたところです。
# A: ほほお熱帯魚ですか。きれいなことでしょうね。
# B: はい、私はエステティシャンをしていて、普段忙しいのでとても癒されます。
# A: 華やかそうなお仕事で羨ましいですね。わたしは先日定年を迎えて自由の身になりました。
# B: そうなんですね。ゆっくりされてくださいね。私はネイリストも目指しているところです。
# A: それでは総合美容家を目指せそうですね。わたしは体で自慢できるのは虫歯がないことぐらいなんで、美しさに磨きをかける方は尊敬します。
# full summary
# A: それでは総合美容家を目指せそうですね。わたしは体で自慢できるのは虫歯がないことぐらいなんで、美しさに磨きをかける方は尊敬します。
# omitted summary
# A: それでは総合美容家を目指せそうですね。わたしは体で自慢できるのは虫歯がないことぐらいなんで、美しさに磨きをかける方は尊敬します。
# similarity
# 1.0000000000000002
# index
# 2
# -----------------
# filename
# PP18.txt
# full dialogue
# A: こんにちは、お元気していましたか？
# B: はい、元気にしています。今、看護師を目指して千葉の看護学校に通っています。
# A: すごいですね、頑張ってくださいね！わたしは地元埼玉から、引っ越して東京で暮らしています。
# B: 東京ですか！時々遊びに行っています。看護師目指しているのに、実は注射苦手なのがネックです。
# A: 看護師さんでもやはり注射が苦手な方がいるのですね。わたしは田舎出身の夏生れですが、雷が苦手なたちです。
# B: そういうこと、ありますよね。ちなみに趣味がヨガなのですが、何か趣味ありますか？
# A: ヨガもやってみたいですね。特にこれと言って趣味はないのですが、地図がちゃんと読めなくて、方向音痴の割に、街歩きが好きなんです。
# B: わたしも方向音痴なので、気持ちわかります。
# A: ですよね、なかなか道は覚えられません。お休みの日なんかは何をされているんですか？
# full summary
# A: ですよね、なかなか道は覚えられません。お休みの日なんかは何をされているんですか？
# omitted summary
# A: ですよね、なかなか道は覚えられません。お休みの日なんかは何をされているんですか？
# similarity
# 1.0000000000000002
# index
# 0
# -----------------
# filename
# PP36.txt
# full dialogue
# A: ねえ、やっぱりわたしって身長高い方だよね？
# B: んー、そう？わたしは男だから、あんまり人の身長を気にしたことがなかったけど。
# A: そう言ってくれる人がいてよかった！また身長が伸びたみたいでさ。わたし目立つことが嫌いなのにこの身長のせいですごく目立ってしまってる気がする。
# B: いいんじゃない？目立ってても、モデルみたいで。
# A: 自分ではそんな風に思えないんだってば。あなたは嫌いなものとかないの？
# B: そう言われれると、たしかにわたしも細すぎる体型がコンプレックスかもしれないなあ。
# A: あなたこそモデル体型だと思うけど。
# B: いやあ、男が細いのは、カッコがつかないよ。サイクリングが好きで、ついつい食べるのを忘れて走り続けちゃうからかな。
# A: だから細いのね。わたしは福島から引っ越してきてこっちの人ってみんなスタイルがいいから驚いたわ。
# B: みんながみんな、そうってわけでもないよ。わたしは国内旅行が好きで、自転車に乗って、島根から東北の方まで走ったりするからね！
# A: それはすごい！趣味の範囲を超えてるわねそれ！
# full summary
# A: それはすごい！自転車で島根から東北の方まで走るなんて、趣味の範囲を超えているわね！
# omitted summary
# A: それはすごい！自転車で島根から東北の方まで走るなんて、趣味の範囲を超えているわね！
# similarity
# 1.0000000000000002
# index
# 3

# %%
# # Show graph
# import matplotlib.pyplot as plt
# DIALOGUE_NUMBER = 4

# result = results.query(f"filename == 'PP{DIALOGUE_NUMBER}.txt'")
# result = result.sort_values("turn", ascending=True)

# with open(f"./dat/PP{DIALOGUE_NUMBER}.txt") as f:
#     dialogue = [l.rstrip() for l in f.readlines()]

# dialogue_with_line_number = []
# for idx, l in enumerate(dialogue):
#     dialogue_with_line_number.append(str(idx) + ". " + l)

# print("\n".join(dialogue_with_line_number))
# result.plot(x="turn", y="similarity")

# %%
# Count number of sentences similarity < 0.9
threshold = 0.89
under_threshold = results["similarity"] < threshold
n_under_threshold = under_threshold.sum()
print(n_under_threshold)
results_under_threshold = results[under_threshold]
bottom_results = results_under_threshold.reset_index()
# print(results_under_threshold)
print(bottom_results)
print(bottom_results["index"] % 4)
# Out:
# 86
#     level_0  filename  turn  \
# 0        19  PP25.txt     9
# 1        28  PP57.txt    12
# 2        20  PP11.txt    10
# 3        20  PP76.txt    10
# 4        21  PP76.txt    10
# ..      ...       ...   ...
# 81       15  PP93.txt     8
# 82       33  PP29.txt    13
# 83       12  PP32.txt     8
# 84        5  PP92.txt     6
# 85       16  PP12.txt     9
#
#                                          full_summary  \
# 0   B: わあ、助かります！私は手先が器用なので、頭皮マッサージをお願いします。ただ、力加減には...
# 1   A: 試してみた結果を教えてね！豚骨ラーメンを1日3食食べて、髪の毛にどんな効果があるか教えてね！
# 2   A: そうなんですよ。宮沢賢治の「銀河鉄道の夜」という本が特におすすめです。物語は少年が銀河...
# 3                   B: なで肩って、しとやかっぽくて良いと思うよ。着物が似合いそう。
# 4                   B: なで肩って、しとやかっぽくて良いと思うよ。着物が似合いそう。
# ..                                                ...
# 81  B: はい、実は飼っている鳥はオウムで、人間の言葉を覚えることができるんですよ。最近は私の名...
# 82            B: 楽しみにしていますね。特に、津餃子の作り方を教えてもらうのが楽しみです。
# 83                            A: 休みの日には何をすることが多いんですか？
# 84     A: 最近はよく波乗りをしています。実は、最近は波が高くても上手に乗れるようになりましたよ！
# 85  B: 漫画のファッションは、普通のものとは違ったデザインやアイデアがあります。その中には奇抜...
#
#                                       omitted_summary  similarity  index
# 0   B: わあ、助かります！私は手先が器用なので、雪かきのコツを教えていただけると嬉しいです。た...   -0.017414    784
# 1                    A: ねえねえ！最近さー、また一段と体重が増えちゃったんだよね。    0.812288   1753
# 2   A: 朝起きるのが辛いときは、目覚ましを何個もかけるといいですよ。私は母親にも起こしてもらっ...    0.813490    341
# 3   A: そんな風に言われたのは初めてだなあ。ありがとう！あなたの言葉で私は励まされて元気になっ...    0.818072   2313
# 4       A: そんな風に褒められたのは初めてだなあ。ありがとう！なんだか気持ちが明るくなってきた。    0.826654   2314
# ..                                                ...         ...    ...
# 81  A: 鳥ですか！いいですね。おしゃべりするなんて賑やかで楽しそうです。鳥が喋ると、家の中がに...    0.887247   2800
# 82                                 B: その話を聞くのが楽しみですね。    0.887268    922
# 83  B: 普段休みの日は、友達とランチに行ったり、映画を見に行ったりすることが多いよ。最近はハイ...    0.887905   1005
# 84  最近は週に2回ほど海に行ってサーフィンを楽しんでいます。波の高さや風の状況によって、適切なボ...    0.889573   2762
# 85  B: そうなんですよ。私がデザイナーとして作る服は、例えば動物の模様や植物の色合いを取り入れ...    0.889999    369
#
# [86 rows x 7 columns]
# 0     0
# 1     1
# 2     1
# 3     1
# 4     2
#      ..
# 81    0
# 82    2
# 83    1
# 84    2
# 85    1
# Name: index, Length: 86, dtype: int64

# %%
count_1=0
count_2=0
count_3=0
count_4=0
for bottom_result in bottom_results["index"]:
    if (bottom_result % 4 == 1):
        count_1 += 1
    if (bottom_result % 4 == 2):
        count_2 += 1
    if (bottom_result % 4 == 3):
        count_3 += 1
    if (bottom_result % 4 == 0):
        count_4 += 1

print("count_1=" + str(count_1))
print("count_2=" + str(count_2))
print("count_3=" + str(count_3))
print("count_4=" + str(count_4))
# Out:
# count_1=40
# count_2=22
# count_3=13
# count_4=11

# %%
# Show histogram
import matplotlib.pyplot as plt

plt.rcParams["font.family"] = "Times New Roman"   # 使用するフォント
plt.rcParams["font.size"] = 20                 # 文字の大きさ

hist = plt.hist((bottom_results["index"] - 1)% 4 + 1)
plt.xlabel("Relative position")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Collect top samples with the same number as under threshold
top_results = results.tail(n_under_threshold)
top_results = top_results.reset_index()
top_threshold = top_results["similarity"].min()
print(top_results)
print(top_threshold)
# Out:
#     level_0  filename  turn  \
# 0        16  PP60.txt     9
# 1        12  PP22.txt     8
# 2         9  PP22.txt     7
# 3        19  PP73.txt     9
# 4        23  PP30.txt    10
# ..      ...       ...   ...
# 81       26  PP96.txt    11
# 82       27  PP96.txt    11
# 83        5  PP10.txt     6
# 84       15  PP18.txt     8
# 85       22  PP36.txt    10
#
#                                          full_summary  \
# 0       B: 食事！いいね、わたしの出身地の名物、牛タンを出してる良いお店を知ってるよ！興味ある？
# 1               A: そうですか、オセロも得意なんですが、今度一緒にオセロをやりませんか？
# 2   B: ゲーム、わたしも好きでよくやりますよ。私は家でゲームをすることが多く、外に出ることが少...
# 3   B: まあ、一応空港会社に勤めているので、上司は外国人で、また外国人観光客にもよく会うことが...
# 4   A: そうなんだ。確かに似てるね。もし心理カウンセラーをやめたら、わたしもキャリアコンサルタ...
# ..                                                ...
# 81        B: そうですね！私たちはそれぞれの仕事で人々の役に立つことを目指して頑張りましょう！
# 82        B: そうですね！私たちはそれぞれの仕事で人々の役に立つことを目指して頑張りましょう！
# 83  A: それでは総合美容家を目指せそうですね。わたしは体で自慢できるのは虫歯がないことぐらいな...
# 84        A: ですよね、なかなか道は覚えられません。お休みの日なんかは何をされているんですか？
# 85       A: それはすごい！自転車で島根から東北の方まで走るなんて、趣味の範囲を超えているわね！
#
#                                       omitted_summary  similarity  index
# 0       B: 食事！いいね、わたしの出身地の名物、牛タンを出してる良いお店を知ってるよ！興味ある？         1.0   1829
# 1               A: そうですか、オセロも得意なんですが、今度一緒にオセロをやりませんか？         1.0    689
# 2   B: ゲーム、わたしも好きでよくやりますよ。私は家でゲームをすることが多く、外に出ることが少...         1.0    686
# 3   B: まあ、一応空港会社に勤めているので、上司は外国人で、また外国人観光客にもよく会うことが...         1.0   2220
# 4   A: そうなんだ。確かに似てるね。もし心理カウンセラーをやめたら、わたしもキャリアコンサルタ...         1.0    948
# ..                                                ...         ...    ...
# 81        B: そうですね！私たちはそれぞれの仕事で人々の役に立つことを目指して頑張りましょう！         1.0   2895
# 82        B: そうですね！私たちはそれぞれの仕事で人々の役に立つことを目指して頑張りましょう！         1.0   2896
# 83  A: それでは総合美容家を目指せそうですね。わたしは体で自慢できるのは虫歯がないことぐらいな...         1.0    290
# 84        A: ですよね、なかなか道は覚えられません。お休みの日なんかは何をされているんですか？         1.0    552
# 85       A: それはすごい！自転車で島根から東北の方まで走るなんて、趣味の範囲を超えているわね！         1.0   1131
#
# [86 rows x 7 columns]
# 1.0000000000000002

# %%
count_1=0
count_2=0
count_3=0
count_4=0
for top_result in top_results["index"]:
    if (top_result % 4 == 1):
        count_1 += 1
    if (top_result % 4 == 2):
        count_2 += 1
    if (top_result % 4 == 3):
        count_3 += 1
    if (top_result % 4 == 0):
        count_4 += 1
print("count_1=" + str(count_1))
print("count_2=" + str(count_2))
print("count_3=" + str(count_3))
print("count_4=" + str(count_4))
# Out:
# count_1=9
# count_2=23
# count_3=26
# count_4=28

# %%
# Show histogram
import matplotlib.pyplot as plt

plt.rcParams["font.family"] = "Times New Roman"   # 使用するフォント
plt.rcParams["font.size"] = 20                 # 文字の大きさ

hist = plt.hist((top_results["index"] - 1)% 4 + 1)
plt.xlabel("Relative position")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Create samples for survey
import time
n_sample = 8
sample_size_low = 4
sample_size_high = 4

samples = []
for i in range(n_sample):
    sample = pd.DataFrame(columns=bottom_results.columns)
    n_rows = 0
    j = 0
    while n_rows < sample_size_low:
        low_candidate = bottom_results.sample(n=1)
        low_candidate["condition"] = "low"
        # print(low_candidate["index"])
        if (int(low_candidate["index"]) % 4 == j):
            sample = pd.concat([sample, low_candidate])
            print(sample["filename"])  
            sample = sample.drop_duplicates(keep="first", subset="filename")
            if (j == len(sample) - 1):
                j+=1
            print(j)
            print(len(sample))
        n_rows = len(sample)
    bottom_results.drop(sample.head(sample_size_low).index, inplace=True)
    print("finished low")
    time.sleep(3)
    j = 0
    while n_rows < sample_size_low + sample_size_high:
        high_candidate = top_results.sample(n=1)
        high_candidate["condition"] = "high"
        if (int(high_candidate["index"]) % 4 == j):
            sample = pd.concat([sample, high_candidate])
            print(sample["filename"])  
            time.sleep(1)
            sample = sample.drop_duplicates(keep="first", subset="filename")
            if (j == len(sample) - 5):
                j+=1
            print(j)
            print(len(sample))
        n_rows = len(sample)
    top_results.drop(sample.tail(sample_size_high).index, inplace=True)

    # Check filename
    print("finished high")
    print(i+1)
      
    samples.append(sample)
    print(sample["filename"])  
    # print(samples)
    print("------------------------------------------------")
    time.sleep(3)
# Out:
# 50    PP80.txt
# Name: filename, dtype: object
# 1
# 1
# 50    PP80.txt
# 74    PP10.txt
# Name: filename, dtype: object
# 2
# 2
# 50    PP80.txt
# 74    PP10.txt
# 72    PP57.txt
# Name: filename, dtype: object
# 3
# 3
# 50     PP80.txt
# 74     PP10.txt
# 72     PP57.txt
# 1     PP103.txt
# Name: filename, dtype: object
# 4
# 4
# finished low
# 50     PP80.txt
# 74     PP10.txt
# 72     PP57.txt
# 1     PP103.txt
# 34      PP4.txt
# Name: filename, dtype: object
# 1
# 5
# 50     PP80.txt
# 74     PP10.txt
# 72     PP57.txt
# 1     PP103.txt
# 34      PP4.txt
# 79     PP22.txt
# Name: filename, dtype: object
# 2
# 6
# 50     PP80.txt
# 74     PP10.txt
# 72     PP57.txt
# 1     PP103.txt
# 34      PP4.txt
# 79     PP22.txt
# 66     PP19.txt
# Name: filename, dtype: object
# 3
# 7
# 50      PP80.txt
# 74      PP10.txt
# 72      PP57.txt
# 1      PP103.txt
# 34       PP4.txt
# 79      PP22.txt
# 66      PP19.txt
# 147     PP26.txt
# Name: filename, dtype: object
# 4
# 8
# finished high
# 1
# 50      PP80.txt
# 74      PP10.txt
# 72      PP57.txt
# 1      PP103.txt
# 34       PP4.txt
# 79      PP22.txt
# 66      PP19.txt
# 147     PP26.txt
# Name: filename, dtype: object
# ------------------------------------------------
# 56    PP90.txt
# Name: filename, dtype: object
# 1
# 1
# 56    PP90.txt
# 25     PP7.txt
# Name: filename, dtype: object
# 2
# 2
# 56    PP90.txt
# 25     PP7.txt
# 19    PP59.txt
# Name: filename, dtype: object
# 3
# 3
# 56      PP90.txt
# 25       PP7.txt
# 19      PP59.txt
# 103    PP133.txt
# Name: filename, dtype: object
# 4
# 4
# finished low
# 56      PP90.txt
# 25       PP7.txt
# 19      PP59.txt
# 103    PP133.txt
# 36     PP114.txt
# Name: filename, dtype: object
# 1
# 5
# 56      PP90.txt
# 25       PP7.txt
# 19      PP59.txt
# 103    PP133.txt
# 36     PP114.txt
# 62      PP18.txt
# Name: filename, dtype: object
# 2
# 6
# 56      PP90.txt
# 25       PP7.txt
# 19      PP59.txt
# 103    PP133.txt
# 36     PP114.txt
# 62      PP18.txt
# 144     PP26.txt
# Name: filename, dtype: object
# 3
# 7
# 56      PP90.txt
# 25       PP7.txt
# 19      PP59.txt
# 103    PP133.txt
# 36     PP114.txt
# 62      PP18.txt
# 144     PP26.txt
# 88      PP68.txt
# Name: filename, dtype: object
# 4
# 8
# finished high
# 2
# 56      PP90.txt
# 25       PP7.txt
# 19      PP59.txt
# 103    PP133.txt
# 36     PP114.txt
# 62      PP18.txt
# 144     PP26.txt
# 88      PP68.txt
# Name: filename, dtype: object
# ------------------------------------------------
# 116    PP56.txt
# Name: filename, dtype: object
# 1
# 1
# 116    PP56.txt
# 30     PP31.txt
# Name: filename, dtype: object
# 2
# 2
# 116    PP56.txt
# 30     PP31.txt
# 101     PP2.txt
# Name: filename, dtype: object
# 3
# 3
# 116     PP56.txt
# 30      PP31.txt
# 101      PP2.txt
# 59     PP130.txt
# Name: filename, dtype: object
# 4
# 4
# finished low
# 116     PP56.txt
# 30      PP31.txt
# 101      PP2.txt
# 59     PP130.txt
# 153     PP14.txt
# Name: filename, dtype: object
# 1
# 5
# 116     PP56.txt
# 30      PP31.txt
# 101      PP2.txt
# 59     PP130.txt
# 153     PP14.txt
# 71     PP145.txt
# Name: filename, dtype: object
# 2
# 6
# 116     PP56.txt
# 30      PP31.txt
# 101      PP2.txt
# 59     PP130.txt
# 153     PP14.txt
# 71     PP145.txt
# 91     PP132.txt
# Name: filename, dtype: object
# 3
# 7
# 116     PP56.txt
# 30      PP31.txt
# 101      PP2.txt
# 59     PP130.txt
# 153     PP14.txt
# 71     PP145.txt
# 91     PP132.txt
# 55      PP63.txt
# Name: filename, dtype: object
# 4
# 8
# finished high
# 3
# 116     PP56.txt
# 30      PP31.txt
# 101      PP2.txt
# 59     PP130.txt
# 153     PP14.txt
# 71     PP145.txt
# 91     PP132.txt
# 55      PP63.txt
# Name: filename, dtype: object
# ------------------------------------------------
# 104    PP133.txt
# Name: filename, dtype: object
# 1
# 1
# 104    PP133.txt
# 43      PP37.txt
# Name: filename, dtype: object
# 2
# 2
# 104    PP133.txt
# 43      PP37.txt
# 65      PP51.txt
# Name: filename, dtype: object
# 3
# 3
# 104    PP133.txt
# 43      PP37.txt
# 65      PP51.txt
# 70     PP118.txt
# Name: filename, dtype: object
# 4
# 4
# finished low
# 104    PP133.txt
# 43      PP37.txt
# 65      PP51.txt
# 70     PP118.txt
# 131     PP61.txt
# Name: filename, dtype: object
# 1
# 5
# 104    PP133.txt
# 43      PP37.txt
# 65      PP51.txt
# 70     PP118.txt
# 131     PP61.txt
# 101     PP57.txt
# Name: filename, dtype: object
# 2
# 6
# 104    PP133.txt
# 43      PP37.txt
# 65      PP51.txt
# 70     PP118.txt
# 131     PP61.txt
# 101     PP57.txt
# 78      PP22.txt
# Name: filename, dtype: object
# 3
# 7
# 104    PP133.txt
# 43      PP37.txt
# 65      PP51.txt
# 70     PP118.txt
# 131     PP61.txt
# 101     PP57.txt
# 78      PP22.txt
# 11       PP3.txt
# Name: filename, dtype: object
# 4
# 8
# finished high
# 4
# 104    PP133.txt
# 43      PP37.txt
# 65      PP51.txt
# 70     PP118.txt
# 131     PP61.txt
# 101     PP57.txt
# 78      PP22.txt
# 11       PP3.txt
# Name: filename, dtype: object
# ------------------------------------------------
# 129    PP60.txt
# Name: filename, dtype: object
# 1
# 1
# 129    PP60.txt
# 6      PP59.txt
# Name: filename, dtype: object
# 2
# 2
# 129    PP60.txt
# 6      PP59.txt
# 124    PP99.txt
# Name: filename, dtype: object
# 3
# 3
# 129    PP60.txt
# 6      PP59.txt
# 124    PP99.txt
# 138    PP57.txt
# Name: filename, dtype: object
# 4
# 4
# finished low
# 129     PP60.txt
# 6       PP59.txt
# 124     PP99.txt
# 138     PP57.txt
# 0      PP123.txt
# Name: filename, dtype: object
# 1
# 5
# 129     PP60.txt
# 6       PP59.txt
# 124     PP99.txt
# 138     PP57.txt
# 0      PP123.txt
# 83     PP145.txt
# Name: filename, dtype: object
# 2
# 6
# 129     PP60.txt
# 6       PP59.txt
# 124     PP99.txt
# 138     PP57.txt
# 0      PP123.txt
# 83     PP145.txt
# 125     PP95.txt
# Name: filename, dtype: object
# 3
# 7
# 129     PP60.txt
# 6       PP59.txt
# 124     PP99.txt
# 138     PP57.txt
# 0      PP123.txt
# 83     PP145.txt
# 125     PP95.txt
# 149    PP148.txt
# Name: filename, dtype: object
# 4
# 8
# finished high
# 5
# 129     PP60.txt
# 6       PP59.txt
# 124     PP99.txt
# 138     PP57.txt
# 0      PP123.txt
# 83     PP145.txt
# 125     PP95.txt
# 149    PP148.txt
# Name: filename, dtype: object
# ------------------------------------------------
# 137    PP59.txt
# Name: filename, dtype: object
# 1
# 1
# 137    PP59.txt
# 122    PP82.txt
# Name: filename, dtype: object
# 2
# 2
# 137    PP59.txt
# 122    PP82.txt
# 95     PP60.txt
# Name: filename, dtype: object
# 3
# 3
# 137    PP59.txt
# 122    PP82.txt
# 95     PP60.txt
# 110     PP9.txt
# Name: filename, dtype: object
# 4
# 4
# finished low
# 137    PP59.txt
# 122    PP82.txt
# 95     PP60.txt
# 110     PP9.txt
# 92     PP21.txt
# Name: filename, dtype: object
# 1
# 5
# 137    PP59.txt
# 122    PP82.txt
# 95     PP60.txt
# 110     PP9.txt
# 92     PP21.txt
# 48     PP78.txt
# Name: filename, dtype: object
# 2
# 6
# 137     PP59.txt
# 122     PP82.txt
# 95      PP60.txt
# 110      PP9.txt
# 92      PP21.txt
# 48      PP78.txt
# 120    PP142.txt
# Name: filename, dtype: object
# 3
# 7
# 137     PP59.txt
# 122     PP82.txt
# 95      PP60.txt
# 110      PP9.txt
# 92      PP21.txt
# 48      PP78.txt
# 120    PP142.txt
# 119     PP11.txt
# Name: filename, dtype: object
# 4
# 8
# finished high
# 6
# 137     PP59.txt
# 122     PP82.txt
# 95      PP60.txt
# 110      PP9.txt
# 92      PP21.txt
# 48      PP78.txt
# 120    PP142.txt
# 119     PP11.txt
# Name: filename, dtype: object
# ------------------------------------------------
# 8    PP125.txt
# Name: filename, dtype: object
# 1
# 1
# 8     PP125.txt
# 73    PP143.txt
# Name: filename, dtype: object
# 2
# 2
# 8     PP125.txt
# 73    PP143.txt
# 16    PP125.txt
# Name: filename, dtype: object
# 2
# 2
# 8     PP125.txt
# 73    PP143.txt
# 79     PP56.txt
# Name: filename, dtype: object
# 3
# 3
# 8     PP125.txt
# 73    PP143.txt
# 79     PP56.txt
# 5     PP119.txt
# Name: filename, dtype: object
# 4
# 4
# finished low
# 8      PP125.txt
# 73     PP143.txt
# 79      PP56.txt
# 5      PP119.txt
# 136     PP84.txt
# Name: filename, dtype: object
# 1
# 5
# 8      PP125.txt
# 73     PP143.txt
# 79      PP56.txt
# 5      PP119.txt
# 136     PP84.txt
# 137     PP60.txt
# Name: filename, dtype: object
# 2
# 6
# 8      PP125.txt
# 73     PP143.txt
# 79      PP56.txt
# 5      PP119.txt
# 136     PP84.txt
# 137     PP60.txt
# 15       PP3.txt
# Name: filename, dtype: object
# 3
# 7
# 8      PP125.txt
# 73     PP143.txt
# 79      PP56.txt
# 5      PP119.txt
# 136     PP84.txt
# 137     PP60.txt
# 15       PP3.txt
# 81     PP145.txt
# Name: filename, dtype: object
# 4
# 8
# finished high
# 7
# 8      PP125.txt
# 73     PP143.txt
# 79      PP56.txt
# 5      PP119.txt
# 136     PP84.txt
# 137     PP60.txt
# 15       PP3.txt
# 81     PP145.txt
# Name: filename, dtype: object
# ------------------------------------------------
# 152    PP51.txt
# Name: filename, dtype: object
# 1
# 1
# 152     PP51.txt
# 109    PP148.txt
# Name: filename, dtype: object
# 2
# 2
# 152     PP51.txt
# 109    PP148.txt
# 87      PP46.txt
# Name: filename, dtype: object
# 3
# 3
# 152     PP51.txt
# 109    PP148.txt
# 87      PP46.txt
# 150     PP55.txt
# Name: filename, dtype: object
# 4
# 4
# finished low
# 152     PP51.txt
# 109    PP148.txt
# 87      PP46.txt
# 150     PP55.txt
# 22      PP36.txt
# Name: filename, dtype: object
# 1
# 5
# 152     PP51.txt
# 109    PP148.txt
# 87      PP46.txt
# 150     PP55.txt
# 22      PP36.txt
# 127     PP89.txt
# Name: filename, dtype: object
# 2
# 6
# 152     PP51.txt
# 109    PP148.txt
# 87      PP46.txt
# 150     PP55.txt
# 22      PP36.txt
# 127     PP89.txt
# 95      PP80.txt
# Name: filename, dtype: object
# 3
# 7
# 152     PP51.txt
# 109    PP148.txt
# 87      PP46.txt
# 150     PP55.txt
# 22      PP36.txt
# 127     PP89.txt
# 95      PP80.txt
# 30     PP101.txt
# Name: filename, dtype: object
# 4
# 8
# finished high
# 8
# 152     PP51.txt
# 109    PP148.txt
# 87      PP46.txt
# 150     PP55.txt
# 22      PP36.txt
# 127     PP89.txt
# 95      PP80.txt
# 30     PP101.txt
# Name: filename, dtype: object
# ------------------------------------------------
# 55    PP138.txt
# Name: filename, dtype: object
# 1
# 1
# 55    PP138.txt
# 7      PP91.txt
# Name: filename, dtype: object
# 2
# 2
# 55     PP138.txt
# 7       PP91.txt
# 115     PP89.txt
# Name: filename, dtype: object
# 3
# 3
# 55     PP138.txt
# 7       PP91.txt
# 115     PP89.txt
# 18      PP40.txt
# Name: filename, dtype: object
# 4
# 4
# finished low
# 55     PP138.txt
# 7       PP91.txt
# 115     PP89.txt
# 18      PP40.txt
# 82     PP145.txt
# Name: filename, dtype: object
# 1
# 5
# 55     PP138.txt
# 7       PP91.txt
# 115     PP89.txt
# 18      PP40.txt
# 82     PP145.txt
# 17      PP43.txt
# Name: filename, dtype: object
# 2
# 6
# 55     PP138.txt
# 7       PP91.txt
# 115     PP89.txt
# 18      PP40.txt
# 82     PP145.txt
# 17      PP43.txt
# 134     PP16.txt
# Name: filename, dtype: object
# 3
# 7
# 55     PP138.txt
# 7       PP91.txt
# 115     PP89.txt
# 18      PP40.txt
# 82     PP145.txt
# 17      PP43.txt
# 134     PP16.txt
# 68      PP20.txt
# Name: filename, dtype: object
# 4
# 8
# finished high
# 9
# 55     PP138.txt
# 7       PP91.txt
# 115     PP89.txt
# 18      PP40.txt
# 82     PP145.txt
# 17      PP43.txt
# 134     PP16.txt
# 68      PP20.txt
# Name: filename, dtype: object
# ------------------------------------------------
# 99    PP114.txt
# Name: filename, dtype: object
# 1
# 1
# 99    PP114.txt
# 98     PP79.txt
# Name: filename, dtype: object
# 2
# 2
# 99     PP114.txt
# 98      PP79.txt
# 151    PP115.txt
# Name: filename, dtype: object
# 3
# 3
# 99     PP114.txt
# 98      PP79.txt
# 151    PP115.txt
# 2      PP103.txt
# Name: filename, dtype: object
# 4
# 4
# finished low
# 99     PP114.txt
# 98      PP79.txt
# 151    PP115.txt
# 2      PP103.txt
# 77      PP70.txt
# Name: filename, dtype: object
# 1
# 5
# 99     PP114.txt
# 98      PP79.txt
# 151    PP115.txt
# 2      PP103.txt
# 77      PP70.txt
# 45     PP146.txt
# Name: filename, dtype: object
# 2
# 6
# 99     PP114.txt
# 98      PP79.txt
# 151    PP115.txt
# 2      PP103.txt
# 77      PP70.txt
# 45     PP146.txt
# 16      PP97.txt
# Name: filename, dtype: object
# 3
# 7
# 99     PP114.txt
# 98      PP79.txt
# 151    PP115.txt
# 2      PP103.txt
# 77      PP70.txt
# 45     PP146.txt
# 16      PP97.txt
# 3       PP36.txt
# Name: filename, dtype: object
# 4
# 8
# finished high
# 10
# 99     PP114.txt
# 98      PP79.txt
# 151    PP115.txt
# 2      PP103.txt
# 77      PP70.txt
# 45     PP146.txt
# 16      PP97.txt
# 3       PP36.txt
# Name: filename, dtype: object
# ------------------------------------------------

# %%
# Create CSV for assistance
import csv

SPEAKERS = ["A: ", "B: "]

for sample_number, sample in enumerate(samples):
    shuffled_sample = sample.sample(frac=1)
    sample_CSV = pd.DataFrame({
        "sample_number": [],
        "dialogue_number": [],
        "full_dialogue": [],
        "assist_utterance": [],
        "omitted_dialogue": [],
        })
    sample_CSV = sample_CSV.astype({
        "sample_number": int,
        "dialogue_number": int,
        "full_dialogue": str,
        "assist_utterance": str,
        "omitted_dialogue": [],
    })
    for dialogue_number, row in enumerate(shuffled_sample.itertuples()):
        with open("./dat/" + row.filename) as f:
            dialogue = [l.rstrip() for l in f.readlines()]
        
        full_dialogue = "\n".join(dialogue[:row.turn + 1])
        if (row.index % 4 == 1):
            omitted_dialogue = "\n\n".join(dialogue[:row.turn - 2] + dialogue[row.turn:row.turn + 1])
        elif (row.index % 4 == 2):
            omitted_dialogue = "\n\n".join(dialogue[:row.turn - 3] + dialogue[row.turn-1:row.turn + 1])
        elif (row.index % 4 == 3):
            omitted_dialogue = "\n\n".join(dialogue[:row.turn - 4] + dialogue[row.turn-2:row.turn + 1])
        else:
            omitted_dialogue = "\n\n".join(dialogue[:row.turn - 5] + dialogue[row.turn-3:row.turn + 1])
            
        sample_CSV = pd.concat([sample_CSV, pd.DataFrame({
            "sample_number": [int(sample_number)],
            "dialogue_number": [int(dialogue_number)],
            "full_dialogue": [full_dialogue],
            "assist_utterance": [""],
            "omitted_dialogue": [omitted_dialogue],
        })])

    csv_filename = "./new/assist/assist{:03}.csv".format(sample_number + 1)
    with open(csv_filename, mode="w", encoding="shift-jis", errors="ignore") as f:
        # ここでデータフレームを開いたファイルにcsvで書き込む
        sample_CSV.to_csv(f)
    print(csv_filename)
# Out:
# ./new/assist/assist001.csv
# ./new/assist/assist002.csv
# ./new/assist/assist003.csv
# ./new/assist/assist004.csv
# ./new/assist/assist005.csv
# ./new/assist/assist006.csv
# ./new/assist/assist007.csv
# ./new/assist/assist008.csv
# ./new/assist/assist009.csv
# ./new/assist/assist010.csv

# %%
# Create CSV
import csv

SPEAKERS = ["A: ", "B: "]

for idx, sample in enumerate(samples):
    shuffled_sample = sample.sample(frac=1)
    sample_CSV = pd.DataFrame({
        "full_dialogue": [],
        "omitted_dialogue": [],
        "core_sentence": [],
        "condition": [],
        "index": [],
        "similarity": [],
        "full_summary": [],
        "omitted_summary": []
        })
    for row in shuffled_sample.itertuples():
        with open("./dat/" + row.filename) as f:
            dialogue = [l.rstrip() for l in f.readlines()]
        
        full_dialogue = "\n\n".join(dialogue[:row.turn + 1])
        if (row.index % 4 == 1):
            omitted_dialogue = "\n\n".join(dialogue[:row.turn - 2] + dialogue[row.turn:row.turn + 1])
        elif (row.index % 4 == 2):
            omitted_dialogue = "\n\n".join(dialogue[:row.turn - 3] + dialogue[row.turn-1:row.turn + 1])
        elif (row.index % 4 == 3):
            omitted_dialogue = "\n\n".join(dialogue[:row.turn - 4] + dialogue[row.turn-2:row.turn + 1])
        else:
            omitted_dialogue = "\n\n".join(dialogue[:row.turn - 5] + dialogue[row.turn-3:row.turn + 1])
        print(row.filename)
        print(row.turn)
        core_sentence = dialogue[row.turn]
        for speaker in SPEAKERS:
            core_sentence = core_sentence.removeprefix(speaker)
        condition = row.condition
        # index = row.index % 4
        index = 4 if row.index % 4 == 0 else row.index % 4
        similarity=row.similarity
        full_summary = row.full_summary
        omitted_summary = row.omitted_summary
        sample_CSV = pd.concat([sample_CSV, pd.DataFrame({
        "full_dialogue": [full_dialogue],
        "omitted_dialogue": [omitted_dialogue],
        "core_sentence": [core_sentence],
        "condition": [condition],
        "index": [index],
        "similarity": [similarity],
        "full_summary": [full_summary],
        "omitted_summary": [omitted_summary]
        })])

    csv_filename = "./new/sample/sample{:03}.csv".format(idx + 1)
    # 一度ファイルオブジェクトをエラー無視して、書き込みで開くようにする
    with open(csv_filename, mode="w", encoding="shift-jis", errors="ignore") as f:
        # ここでデータフレームを開いたファイルにcsvで書き込む
        sample_CSV.to_csv(f)

    # sample_CSV.to_csv(csv_filename, encoding="utf-8")
    print(csv_filename)
print("done")
# Out:
# PP26.txt
# 6
# PP4.txt
# 10
# PP10.txt
# 11
# PP80.txt
# 10
# PP103.txt
# 11
# PP19.txt
# 8
# PP57.txt
# 12
# PP22.txt
# 5
# ./new/sample/sample001.csv
# PP68.txt
# 10
# PP18.txt
# 11
# PP133.txt
# 12
# PP59.txt
# 5
# PP7.txt
# 12
# PP90.txt
# 11
# PP26.txt
# 6
# PP114.txt
# 8
# ./new/sample/sample002.csv
# PP31.txt
# 12
# PP14.txt
# 9
# PP132.txt
# 6
# PP2.txt
# 14
# PP145.txt
# 6
# PP63.txt
# 12
# PP130.txt
# 12
# PP56.txt
# 12
# ./new/sample/sample003.csv
# PP57.txt
# 10
# PP61.txt
# 9
# PP51.txt
# 12
# PP37.txt
# 5
# PP3.txt
# 7
# PP22.txt
# 5
# PP118.txt
# 8
# PP133.txt
# 12
# ./new/sample/sample004.csv
# PP60.txt
# 10
# PP99.txt
# 11
# PP57.txt
# 7
# PP145.txt
# 9
# PP95.txt
# 10
# PP148.txt
# 8
# PP123.txt
# 9
# PP59.txt
# 9
# ./new/sample/sample005.csv
# PP9.txt
# 12
# PP142.txt
# 12
# PP78.txt
# 10
# PP11.txt
# 11
# PP82.txt
# 8
# PP60.txt
# 11
# PP21.txt
# 5
# PP59.txt
# 5
# ./new/sample/sample006.csv
# PP3.txt
# 7
# PP60.txt
# 5
# PP143.txt
# 12
# PP84.txt
# 5
# PP145.txt
# 8
# PP125.txt
# 12
# PP119.txt
# 12
# PP56.txt
# 12
# ./new/sample/sample007.csv
# PP46.txt
# 11
# PP51.txt
# 5
# PP148.txt
# 10
# PP101.txt
# 10
# PP89.txt
# 7
# PP55.txt
# 6
# PP80.txt
# 6
# PP36.txt
# 8
# ./new/sample/sample008.csv
# PP20.txt
# 10
# PP40.txt
# 12
# PP91.txt
# 5
# PP138.txt
# 10
# PP145.txt
# 8
# PP16.txt
# 11
# PP89.txt
# 11
# PP43.txt
# 6
# ./new/sample/sample009.csv
# PP97.txt
# 10
# PP36.txt
# 11
# PP115.txt
# 11
# PP79.txt
# 11
# PP103.txt
# 11
# PP114.txt
# 10
# PP70.txt
# 8
# PP146.txt
# 8
# ./new/sample/sample010.csv
# done

# %%
# Create tex
import pandas as pd
n_samples = 10

for survey_idx in range(n_samples):

    SURVEY_NUMBER = survey_idx + 1
    csv_filename = "./new/sample/sample{:03}.csv".format(SURVEY_NUMBER)
    sample_CSV = pd.read_csv(csv_filename, encoding="shift-jis")
    print(sample_CSV)
    head_path = "./tex/head.tex"
    with open(head_path) as head_file:
        head_tex = head_file.read()
    tail_path = "./tex/tail.tex"
    with open(tail_path) as tail_file:
        tail_tex = tail_file.read()

    for idx, row in enumerate(sample_CSV.itertuples()):
        underlined_core_sentence = "\\ul{" + row.core_sentence + "}"
        underlined_full = row.full_dialogue.replace(row.core_sentence, underlined_core_sentence)
        full_path = "./new/data/" + str(SURVEY_NUMBER).zfill(3) + "_" + str(idx).zfill(3) + "full.tex"
        with open(full_path, mode='w') as output_file:
            output_file.write(head_tex)
            output_file.write(underlined_full)
            output_file.write(tail_tex)

        full_name = "new/data/" + str(SURVEY_NUMBER).zfill(3) + "_" + str(idx).zfill(3) + "full"
        # !ptex2pdf -l {full_name} -output-directory "new/data/"


        underlined_omitted = row.omitted_dialogue.replace(row.core_sentence, underlined_core_sentence)
        omitted_path = "./new/data/" + str(SURVEY_NUMBER).zfill(3) + "_" + str(idx).zfill(3) + "omitted.tex"
        with open(omitted_path, mode='w') as output_file:
            output_file.write(head_tex)
            output_file.write(underlined_omitted)
            output_file.write(tail_tex)

        omitted_name = "new/data/" + str(SURVEY_NUMBER).zfill(3) + "_" + str(idx).zfill(3) + "omitted"
        # !ptex2pdf -l {omitted_name} -output-directory "new/data/"
# Out:
#    Unnamed: 0                                      full_dialogue  \
# 0           0  A: こんにちは！わたしは今趣味のDIYにハマっているのだけど、あなたもなにかハマっているこ...
# 1           0  A: こんばんは、調子はいかがですか？\n\nB: こんばんは。調子はまぁまぁかな？70年代...
# 2           0  A: こんにちは。お話して大丈夫ですか？\n\nB: はい、大丈夫です。今、飼っている熱帯魚...
# 3           0  A: あなたって高校のとき何か部に所属してた？\n\nB: ううん。帰宅部だったよ。あなたは...
# 4           0  A: ああ、もう！ダンスの練習に行ったら、友達がみんな遅刻してきたの！参っちゃう！\n\nB...
# 5           0  A: こんにちは。私は、看護師を目指して学校に通っています。あなたは何のお仕事をされています...
# 6           0  A: ねえねえ！最近さー、また一段と体重が増えちゃったんだよね。\n\nB: そうなんだ？わ...
# 7           0  A: こんばんは、寒くなってきましたが、石川県に転勤してきて、ますます寒さが身に染みています...
#
#                                     omitted_dialogue  \
# 0  A: こんにちは！わたしは今趣味のDIYにハマっているのだけど、あなたもなにかハマっているこ...
# 1  A: こんばんは、調子はいかがですか？\n\nB: こんばんは。調子はまぁまぁかな？70年代...
# 2  A: こんにちは。お話して大丈夫ですか？\n\nB: はい、大丈夫です。今、飼っている熱帯魚...
# 3  A: あなたって高校のとき何か部に所属してた？\n\nB: ううん。帰宅部だったよ。あなたは...
# 4  A: ああ、もう！ダンスの練習に行ったら、友達がみんな遅刻してきたの！参っちゃう！\n\nB...
# 5  A: こんにちは。私は、看護師を目指して学校に通っています。あなたは何のお仕事をされています...
# 6  A: ねえねえ！最近さー、また一段と体重が増えちゃったんだよね。\n\nB: そうなんだ？わ...
# 7  A: こんばんは、寒くなってきましたが、石川県に転勤してきて、ますます寒さが身に染みています...
#
#                                        core_sentence condition  index  \
# 0       ええ、そうですね。ゴルフなんてちょっと憧れてしまうけど、どうです？やっぱり難しいですか？      high    3.0
# 1               わたしには兄がいますがよくチアリーダーに応援して欲しいと言ってましたね。      high    4.0
# 2                                     それは近いですね！奇遇です。       low    1.0
# 3                わたしと違ってなんだかかっこいい思い出だね。アニメオタクには眩しいよ。       low    4.0
# 4                      そう言ってもらえると、自分に自信が出てくるわ。ありがとう。       low    3.0
# 5                      そうなんですね、私も看護師の勉強忙しくて、彼氏いないです。      high    2.0
# 6                                           結果を教えてね！       low    2.0
# 7  飲み会ですか。それは大変そうですね。私はソーシャルワーカーなので、滅多に飲み会なくて逆に寂し...      high    1.0
#
#    similarity                                       full_summary  \
# 0    1.000000                    私はゴルフに興味がありますが、実際にやってみると難しいですか？
# 1    1.000000              兄は私に対して、自分がチアリーダーを応援してほしいと頻繁に言っていました。
# 2    0.850190          宮城の出身なので、岩手の方とは近いですね。私たちの出身地が近いことは、偶然ですね。
# 3    0.838097  あなたの学生時代の思い出は、私とは違ってかっこいいものだね。アニメ好きにとっては、とても魅力...
# 4    0.781108           あなたが私のことをそう言ってくれると、私は自信を持つことができます。ありがとう。
# 5    1.000000                           私は看護師の勉強が忙しくて、彼氏がいないんです。
# 6    0.849349                            試してみた後に、その結果を私に教えてください。
# 7    1.000000              私はソーシャルワーカーなので、普段はあまり飲み会がなくて、逆に寂しいです。
#
#                                      omitted_summary
# 0                    私はゴルフに興味がありますが、実際にやってみると難しいですか？
# 1              兄は私に対して、自分がチアリーダーを応援してほしいと頻繁に言っていました。
# 2                       私も髪の毛が薄いんですよ。私たちは似たような境遇ですね。
# 3  B: 学生時代は海の近くの街に住んでて、通学の時に海沿いの道を自転車で通ってたから、今でも海...
# 4  A: へえー！70年代って言ったら、フォークとか流行ってた頃よね。色んな時代を見てきたからこ...
# 5                           私は看護師の勉強が忙しくて、彼氏がいないんです。
# 6                       試してみたら、髪の毛がツヤツヤになったかどうか教えてね！
# 7              私はソーシャルワーカーなので、普段はあまり飲み会がなくて、逆に寂しいです。
# This is ptex2pdf[.lua] version 20200520.0.
# Processing new/data/001_000full
# This is e-pTeX, Version 3.141592653-p3.9.0-210218-2.6 (utf8.euc) (TeX Live 2021) (preloaded format=platex)
#  restricted \write18 enabled.
# entering extended mode
# (./new/data/001_000full.tex
# pLaTeX2e <2020-10-01>+2 (based on LaTeX2e <2020-10-01> patch level 4)
# L3 programming layer <2021-02-18>
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amscls/amsart.cls
# Document Class: amsart 2020/05/29 v2.20.6
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (I search kanjifont definition file: . . ) (I search font definition file: . .
# . . . . . ) (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsa.fd)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/amsfonts.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/geometry/geometry.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/generic/iftex/ifvtex.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/iftex/iftex.sty)))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/graphicx.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/graphics.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/trig.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-cfg/graphics.cfg)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-def/dvips.def)))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/amssymb.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/epstopdf-pkg/epstopdf.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/infwarerr/infwarerr.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/grfext/grfext.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/kvdefinekeys/kvdefinekeys.sty))
#  (/usr/local/texlive/2021/texmf-dist/tex/latex/kvoptions/kvoptions.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/ltxcmds/ltxcmds.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/generic/kvsetkeys/kvsetkeys.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/generic/pdftexcmds/pdftexcmds.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/epstopdf-pkg/epstopdf-base.sty
#
# Package epstopdf Warning: Drivers other than `pdftex' and `luatex' are not supp
# orted.
#
# )) (/usr/local/texlive/2021/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-cfg/color.cfg))
# (/usr/local/texlive/texmf-local/tex/latex/udline/udline.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/l3backend/l3backend-dvips.def)
# (new/data//001_000full.aux)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsa.fd)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsb.fd)
# *geometry* driver: auto-detecting
# *geometry* detected driver: dvips
# [1] (new/data//001_000full.aux) )
# Output written on new/data//001_000full.dvi (1 page, 2840 bytes).
# Transcript written on new/data//001_000full.log.
# new/data//001_000full.dvi -> new/data//001_000full.pdf
# [1]
# 27135 bytes written
# new/data//001_000full.pdf generated by dvipdfmx.
# This is ptex2pdf[.lua] version 20200520.0.
# Processing new/data/001_000omitted
# This is e-pTeX, Version 3.141592653-p3.9.0-210218-2.6 (utf8.euc) (TeX Live 2021) (preloaded format=platex)
#  restricted \write18 enabled.
# entering extended mode
# (./new/data/001_000omitted.tex
# pLaTeX2e <2020-10-01>+2 (based on LaTeX2e <2020-10-01> patch level 4)
# L3 programming layer <2021-02-18>
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amscls/amsart.cls
# Document Class: amsart 2020/05/29 v2.20.6
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (I search kanjifont definition file: . . ) (I search font definition file: . .
# . . . . . ) (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsa.fd)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/amsfonts.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/geometry/geometry.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/generic/iftex/ifvtex.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/iftex/iftex.sty)))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/graphicx.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/graphics.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/trig.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-cfg/graphics.cfg)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-def/dvips.def)))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/amssymb.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/epstopdf-pkg/epstopdf.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/infwarerr/infwarerr.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/grfext/grfext.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/kvdefinekeys/kvdefinekeys.sty))
#  (/usr/local/texlive/2021/texmf-dist/tex/latex/kvoptions/kvoptions.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/ltxcmds/ltxcmds.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/generic/kvsetkeys/kvsetkeys.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/generic/pdftexcmds/pdftexcmds.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/epstopdf-pkg/epstopdf-base.sty
#
# Package epstopdf Warning: Drivers other than `pdftex' and `luatex' are not supp
# orted.
#
# )) (/usr/local/texlive/2021/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-cfg/color.cfg))
# (/usr/local/texlive/texmf-local/tex/latex/udline/udline.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/l3backend/l3backend-dvips.def)
# (new/data//001_000omitted.aux)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsa.fd)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsb.fd)
# *geometry* driver: auto-detecting
# *geometry* detected driver: dvips
# [1] (new/data//001_000omitted.aux) )
# Output written on new/data//001_000omitted.dvi (1 page, 2576 bytes).
# Transcript written on new/data//001_000omitted.log.
# new/data//001_000omitted.dvi -> new/data//001_000omitted.pdf
# [1]
# 24474 bytes written
# new/data//001_000omitted.pdf generated by dvipdfmx.
# This is ptex2pdf[.lua] version 20200520.0.
# Processing new/data/001_001full
# This is e-pTeX, Version 3.141592653-p3.9.0-210218-2.6 (utf8.euc) (TeX Live 2021) (preloaded format=platex)
#  restricted \write18 enabled.
# entering extended mode
# (./new/data/001_001full.tex
# pLaTeX2e <2020-10-01>+2 (based on LaTeX2e <2020-10-01> patch level 4)
# L3 programming layer <2021-02-18>
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amscls/amsart.cls
# Document Class: amsart 2020/05/29 v2.20.6
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (I search kanjifont definition file: . . ) (I search font definition file: . .
# . . . . . ) (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsa.fd)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/amsfonts.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/geometry/geometry.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/generic/iftex/ifvtex.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/iftex/iftex.sty)))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/graphicx.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/graphics.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/trig.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-cfg/graphics.cfg)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-def/dvips.def)))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/amssymb.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/epstopdf-pkg/epstopdf.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/infwarerr/infwarerr.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/grfext/grfext.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/kvdefinekeys/kvdefinekeys.sty))
#  (/usr/local/texlive/2021/texmf-dist/tex/latex/kvoptions/kvoptions.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/ltxcmds/ltxcmds.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/generic/kvsetkeys/kvsetkeys.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/generic/pdftexcmds/pdftexcmds.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/epstopdf-pkg/epstopdf-base.sty
#
# Package epstopdf Warning: Drivers other than `pdftex' and `luatex' are not supp
# orted.
#
# )) (/usr/local/texlive/2021/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-cfg/color.cfg))
# (/usr/local/texlive/texmf-local/tex/latex/udline/udline.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/l3backend/l3backend-dvips.def)
# (new/data//001_001full.aux)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsa.fd)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsb.fd)
# *geometry* driver: auto-detecting
# *geometry* detected driver: dvips
# [1] (new/data//001_001full.aux) )
# Output written on new/data//001_001full.dvi (1 page, 3520 bytes).
# Transcript written on new/data//001_001full.log.
# new/data//001_001full.dvi -> new/data//001_001full.pdf
# [1]
# 32711 bytes written
# new/data//001_001full.pdf generated by dvipdfmx.
# This is ptex2pdf[.lua] version 20200520.0.
# Processing new/data/001_001omitted
# This is e-pTeX, Version 3.141592653-p3.9.0-210218-2.6 (utf8.euc) (TeX Live 2021) (preloaded format=platex)
#  restricted \write18 enabled.
# entering extended mode
# (./new/data/001_001omitted.tex
# pLaTeX2e <2020-10-01>+2 (based on LaTeX2e <2020-10-01> patch level 4)
# L3 programming layer <2021-02-18>
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amscls/amsart.cls
# Document Class: amsart 2020/05/29 v2.20.6
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (I search kanjifont definition file: . . ) (I search font definition file: . .
# . . . . . ) (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsa.fd)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/amsfonts.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/geometry/geometry.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/generic/iftex/ifvtex.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/iftex/iftex.sty)))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/graphicx.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/graphics.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/trig.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-cfg/graphics.cfg)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-def/dvips.def)))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/amssymb.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/epstopdf-pkg/epstopdf.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/infwarerr/infwarerr.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/grfext/grfext.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/kvdefinekeys/kvdefinekeys.sty))
#  (/usr/local/texlive/2021/texmf-dist/tex/latex/kvoptions/kvoptions.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/ltxcmds/ltxcmds.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/generic/kvsetkeys/kvsetkeys.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/generic/pdftexcmds/pdftexcmds.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/epstopdf-pkg/epstopdf-base.sty
#
# Package epstopdf Warning: Drivers other than `pdftex' and `luatex' are not supp
# orted.
#
# )) (/usr/local/texlive/2021/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-cfg/color.cfg))
# (/usr/local/texlive/texmf-local/tex/latex/udline/udline.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/l3backend/l3backend-dvips.def)
# (new/data//001_001omitted.aux)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsa.fd)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsb.fd)
# *geometry* driver: auto-detecting
# *geometry* detected driver: dvips
# [1] (new/data//001_001omitted.aux) )
# Output written on new/data//001_001omitted.dvi (1 page, 3176 bytes).
# Transcript written on new/data//001_001omitted.log.
# new/data//001_001omitted.dvi -> new/data//001_001omitted.pdf
# [1]
# 29553 bytes written
# new/data//001_001omitted.pdf generated by dvipdfmx.
# This is ptex2pdf[.lua] version 20200520.0.
# Processing new/data/001_002full
# This is e-pTeX, Version 3.141592653-p3.9.0-210218-2.6 (utf8.euc) (TeX Live 2021) (preloaded format=platex)
#  restricted \write18 enabled.
# entering extended mode
# (./new/data/001_002full.tex
# pLaTeX2e <2020-10-01>+2 (based on LaTeX2e <2020-10-01> patch level 4)
# L3 programming layer <2021-02-18>
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amscls/amsart.cls
# Document Class: amsart 2020/05/29 v2.20.6
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (I search kanjifont definition file: . . ) (I search font definition file: . .
# . . . . . ) (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsa.fd)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/amsfonts.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/geometry/geometry.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/generic/iftex/ifvtex.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/iftex/iftex.sty)))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/graphicx.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/graphics.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/trig.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-cfg/graphics.cfg)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-def/dvips.def)))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/amssymb.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/epstopdf-pkg/epstopdf.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/infwarerr/infwarerr.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/grfext/grfext.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/kvdefinekeys/kvdefinekeys.sty))
#  (/usr/local/texlive/2021/texmf-dist/tex/latex/kvoptions/kvoptions.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/ltxcmds/ltxcmds.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/generic/kvsetkeys/kvsetkeys.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/generic/pdftexcmds/pdftexcmds.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/epstopdf-pkg/epstopdf-base.sty
#
# Package epstopdf Warning: Drivers other than `pdftex' and `luatex' are not supp
# orted.
#
# )) (/usr/local/texlive/2021/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-cfg/color.cfg))
# (/usr/local/texlive/texmf-local/tex/latex/udline/udline.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/l3backend/l3backend-dvips.def)
# (new/data//001_002full.aux)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsa.fd)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsb.fd)
# *geometry* driver: auto-detecting
# *geometry* detected driver: dvips
# [1] (new/data//001_002full.aux) )
# Output written on new/data//001_002full.dvi (1 page, 2488 bytes).
# Transcript written on new/data//001_002full.log.
# new/data//001_002full.dvi -> new/data//001_002full.pdf
# [1]
# 31923 bytes written
# new/data//001_002full.pdf generated by dvipdfmx.
# This is ptex2pdf[.lua] version 20200520.0.
# Processing new/data/001_002omitted
# This is e-pTeX, Version 3.141592653-p3.9.0-210218-2.6 (utf8.euc) (TeX Live 2021) (preloaded format=platex)
#  restricted \write18 enabled.
# entering extended mode
# (./new/data/001_002omitted.tex
# pLaTeX2e <2020-10-01>+2 (based on LaTeX2e <2020-10-01> patch level 4)
# L3 programming layer <2021-02-18>
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amscls/amsart.cls
# Document Class: amsart 2020/05/29 v2.20.6
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (I search kanjifont definition file: . . ) (I search font definition file: . .
# . . . . . ) (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsa.fd)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/amsfonts.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/geometry/geometry.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/generic/iftex/ifvtex.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/iftex/iftex.sty)))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/graphicx.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/graphics.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/trig.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-cfg/graphics.cfg)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-def/dvips.def)))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/amssymb.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/epstopdf-pkg/epstopdf.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/infwarerr/infwarerr.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/grfext/grfext.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/kvdefinekeys/kvdefinekeys.sty))
#  (/usr/local/texlive/2021/texmf-dist/tex/latex/kvoptions/kvoptions.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/ltxcmds/ltxcmds.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/generic/kvsetkeys/kvsetkeys.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/generic/pdftexcmds/pdftexcmds.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/epstopdf-pkg/epstopdf-base.sty
#
# Package epstopdf Warning: Drivers other than `pdftex' and `luatex' are not supp
# orted.
#
# )) (/usr/local/texlive/2021/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-cfg/color.cfg))
# (/usr/local/texlive/texmf-local/tex/latex/udline/udline.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/l3backend/l3backend-dvips.def)
# (new/data//001_002omitted.aux)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsa.fd)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsb.fd)
# *geometry* driver: auto-detecting
# *geometry* detected driver: dvips
# [1] (new/data//001_002omitted.aux) )
# Output written on new/data//001_002omitted.dvi (1 page, 2196 bytes).
# Transcript written on new/data//001_002omitted.log.
# new/data//001_002omitted.dvi -> new/data//001_002omitted.pdf
# [1]
# 29554 bytes written
# new/data//001_002omitted.pdf generated by dvipdfmx.
# This is ptex2pdf[.lua] version 20200520.0.
# Processing new/data/001_003full
# This is e-pTeX, Version 3.141592653-p3.9.0-210218-2.6 (utf8.euc) (TeX Live 2021) (preloaded format=platex)
#  restricted \write18 enabled.
# entering extended mode
# (./new/data/001_003full.tex
# pLaTeX2e <2020-10-01>+2 (based on LaTeX2e <2020-10-01> patch level 4)
# L3 programming layer <2021-02-18>
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amscls/amsart.cls
# Document Class: amsart 2020/05/29 v2.20.6
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (I search kanjifont definition file: . . ) (I search font definition file: . .
# . . . . . ) (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsa.fd)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/amsfonts.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/geometry/geometry.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/generic/iftex/ifvtex.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/iftex/iftex.sty)))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/graphicx.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/graphics.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/trig.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-cfg/graphics.cfg)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-def/dvips.def)))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/amssymb.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/epstopdf-pkg/epstopdf.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/infwarerr/infwarerr.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/grfext/grfext.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/kvdefinekeys/kvdefinekeys.sty))
#  (/usr/local/texlive/2021/texmf-dist/tex/latex/kvoptions/kvoptions.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/ltxcmds/ltxcmds.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/generic/kvsetkeys/kvsetkeys.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/generic/pdftexcmds/pdftexcmds.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/epstopdf-pkg/epstopdf-base.sty
#
# Package epstopdf Warning: Drivers other than `pdftex' and `luatex' are not supp
# orted.
#
# )) (/usr/local/texlive/2021/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-cfg/color.cfg))
# (/usr/local/texlive/texmf-local/tex/latex/udline/udline.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/l3backend/l3backend-dvips.def)
# (new/data//001_003full.aux)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsa.fd)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsb.fd)
# *geometry* driver: auto-detecting
# *geometry* detected driver: dvips
# [1] (new/data//001_003full.aux) )
# Output written on new/data//001_003full.dvi (1 page, 3468 bytes).
# Transcript written on new/data//001_003full.log.
# new/data//001_003full.dvi -> new/data//001_003full.pdf
# [1]
# 39581 bytes written
# new/data//001_003full.pdf generated by dvipdfmx.
# This is ptex2pdf[.lua] version 20200520.0.
# Processing new/data/001_003omitted
# This is e-pTeX, Version 3.141592653-p3.9.0-210218-2.6 (utf8.euc) (TeX Live 2021) (preloaded format=platex)
#  restricted \write18 enabled.
# entering extended mode
# (./new/data/001_003omitted.tex
# pLaTeX2e <2020-10-01>+2 (based on LaTeX2e <2020-10-01> patch level 4)
# L3 programming layer <2021-02-18>
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amscls/amsart.cls
# Document Class: amsart 2020/05/29 v2.20.6
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (I search kanjifont definition file: . . ) (I search font definition file: . .
# . . . . . ) (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsa.fd)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/amsfonts.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/geometry/geometry.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/generic/iftex/ifvtex.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/iftex/iftex.sty)))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/graphicx.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/graphics.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/trig.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-cfg/graphics.cfg)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-def/dvips.def)))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/amssymb.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/epstopdf-pkg/epstopdf.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/infwarerr/infwarerr.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/grfext/grfext.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/kvdefinekeys/kvdefinekeys.sty))
#  (/usr/local/texlive/2021/texmf-dist/tex/latex/kvoptions/kvoptions.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/ltxcmds/ltxcmds.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/generic/kvsetkeys/kvsetkeys.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/generic/pdftexcmds/pdftexcmds.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/epstopdf-pkg/epstopdf-base.sty
#
# Package epstopdf Warning: Drivers other than `pdftex' and `luatex' are not supp
# orted.
#
# )) (/usr/local/texlive/2021/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-cfg/color.cfg))
# (/usr/local/texlive/texmf-local/tex/latex/udline/udline.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/l3backend/l3backend-dvips.def)
# (new/data//001_003omitted.aux)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsa.fd)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsb.fd)
# *geometry* driver: auto-detecting
# *geometry* detected driver: dvips
# [1] (new/data//001_003omitted.aux) )
# Output written on new/data//001_003omitted.dvi (1 page, 2972 bytes).
# Transcript written on new/data//001_003omitted.log.
# new/data//001_003omitted.dvi -> new/data//001_003omitted.pdf
# [1]
# 33766 bytes written
# new/data//001_003omitted.pdf generated by dvipdfmx.
# This is ptex2pdf[.lua] version 20200520.0.
# Processing new/data/001_004full
# This is e-pTeX, Version 3.141592653-p3.9.0-210218-2.6 (utf8.euc) (TeX Live 2021) (preloaded format=platex)
#  restricted \write18 enabled.
# entering extended mode
# (./new/data/001_004full.tex
# pLaTeX2e <2020-10-01>+2 (based on LaTeX2e <2020-10-01> patch level 4)
# L3 programming layer <2021-02-18>
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amscls/amsart.cls
# Document Class: amsart 2020/05/29 v2.20.6
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (I search kanjifont definition file: . . ) (I search font definition file: . .
# . . . . . ) (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsa.fd)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/amsfonts.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/geometry/geometry.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/generic/iftex/ifvtex.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/iftex/iftex.sty)))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/graphicx.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/graphics.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/trig.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-cfg/graphics.cfg)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-def/dvips.def)))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/amssymb.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/epstopdf-pkg/epstopdf.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/infwarerr/infwarerr.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/grfext/grfext.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/kvdefinekeys/kvdefinekeys.sty))
#  (/usr/local/texlive/2021/texmf-dist/tex/latex/kvoptions/kvoptions.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/ltxcmds/ltxcmds.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/generic/kvsetkeys/kvsetkeys.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/generic/pdftexcmds/pdftexcmds.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/epstopdf-pkg/epstopdf-base.sty
#
# Package epstopdf Warning: Drivers other than `pdftex' and `luatex' are not supp
# orted.
#
# )) (/usr/local/texlive/2021/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-cfg/color.cfg))
# (/usr/local/texlive/texmf-local/tex/latex/udline/udline.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/l3backend/l3backend-dvips.def)
# (new/data//001_004full.aux)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsa.fd)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsb.fd)
# *geometry* driver: auto-detecting
# *geometry* detected driver: dvips
# [1] (new/data//001_004full.aux) )
# Output written on new/data//001_004full.dvi (1 page, 3732 bytes).
# Transcript written on new/data//001_004full.log.
# new/data//001_004full.dvi -> new/data//001_004full.pdf
# [1]
# 33830 bytes written
# new/data//001_004full.pdf generated by dvipdfmx.
# This is ptex2pdf[.lua] version 20200520.0.
# Processing new/data/001_004omitted
# This is e-pTeX, Version 3.141592653-p3.9.0-210218-2.6 (utf8.euc) (TeX Live 2021) (preloaded format=platex)
#  restricted \write18 enabled.
# entering extended mode
# (./new/data/001_004omitted.tex
# pLaTeX2e <2020-10-01>+2 (based on LaTeX2e <2020-10-01> patch level 4)
# L3 programming layer <2021-02-18>
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amscls/amsart.cls
# Document Class: amsart 2020/05/29 v2.20.6
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (I search kanjifont definition file: . . ) (I search font definition file: . .
# . . . . . ) (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsa.fd)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/amsfonts.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/geometry/geometry.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/generic/iftex/ifvtex.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/iftex/iftex.sty)))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/graphicx.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/graphics.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/trig.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-cfg/graphics.cfg)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-def/dvips.def)))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/amssymb.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/epstopdf-pkg/epstopdf.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/infwarerr/infwarerr.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/grfext/grfext.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/kvdefinekeys/kvdefinekeys.sty))
#  (/usr/local/texlive/2021/texmf-dist/tex/latex/kvoptions/kvoptions.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/ltxcmds/ltxcmds.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/generic/kvsetkeys/kvsetkeys.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/generic/pdftexcmds/pdftexcmds.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/epstopdf-pkg/epstopdf-base.sty
#
# Package epstopdf Warning: Drivers other than `pdftex' and `luatex' are not supp
# orted.
#
# )) (/usr/local/texlive/2021/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-cfg/color.cfg))
# (/usr/local/texlive/texmf-local/tex/latex/udline/udline.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/l3backend/l3backend-dvips.def)
# (new/data//001_004omitted.aux)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsa.fd)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsb.fd)
# *geometry* driver: auto-detecting
# *geometry* detected driver: dvips
# [1] (new/data//001_004omitted.aux) )
# Output written on new/data//001_004omitted.dvi (1 page, 3500 bytes).
# Transcript written on new/data//001_004omitted.log.
# new/data//001_004omitted.dvi -> new/data//001_004omitted.pdf
# [1]
# 32824 bytes written
# new/data//001_004omitted.pdf generated by dvipdfmx.
# This is ptex2pdf[.lua] version 20200520.0.
# Processing new/data/001_005full
# This is e-pTeX, Version 3.141592653-p3.9.0-210218-2.6 (utf8.euc) (TeX Live 2021) (preloaded format=platex)
#  restricted \write18 enabled.
# entering extended mode
# (./new/data/001_005full.tex
# pLaTeX2e <2020-10-01>+2 (based on LaTeX2e <2020-10-01> patch level 4)
# L3 programming layer <2021-02-18>
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amscls/amsart.cls
# Document Class: amsart 2020/05/29 v2.20.6
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (I search kanjifont definition file: . . ) (I search font definition file: . .
# . . . . . ) (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsa.fd)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/amsfonts.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/geometry/geometry.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/generic/iftex/ifvtex.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/iftex/iftex.sty)))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/graphicx.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/graphics.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/trig.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-cfg/graphics.cfg)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-def/dvips.def)))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/amssymb.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/epstopdf-pkg/epstopdf.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/infwarerr/infwarerr.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/grfext/grfext.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/kvdefinekeys/kvdefinekeys.sty))
#  (/usr/local/texlive/2021/texmf-dist/tex/latex/kvoptions/kvoptions.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/ltxcmds/ltxcmds.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/generic/kvsetkeys/kvsetkeys.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/generic/pdftexcmds/pdftexcmds.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/epstopdf-pkg/epstopdf-base.sty
#
# Package epstopdf Warning: Drivers other than `pdftex' and `luatex' are not supp
# orted.
#
# )) (/usr/local/texlive/2021/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-cfg/color.cfg))
# (/usr/local/texlive/texmf-local/tex/latex/udline/udline.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/l3backend/l3backend-dvips.def)
# (new/data//001_005full.aux)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsa.fd)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsb.fd)
# *geometry* driver: auto-detecting
# *geometry* detected driver: dvips
# [1] (new/data//001_005full.aux) )
# Output written on new/data//001_005full.dvi (1 page, 2768 bytes).
# Transcript written on new/data//001_005full.log.
# new/data//001_005full.dvi -> new/data//001_005full.pdf
# [1]
# 27977 bytes written
# new/data//001_005full.pdf generated by dvipdfmx.
# This is ptex2pdf[.lua] version 20200520.0.
# Processing new/data/001_005omitted
# This is e-pTeX, Version 3.141592653-p3.9.0-210218-2.6 (utf8.euc) (TeX Live 2021) (preloaded format=platex)
#  restricted \write18 enabled.
# entering extended mode
# (./new/data/001_005omitted.tex
# pLaTeX2e <2020-10-01>+2 (based on LaTeX2e <2020-10-01> patch level 4)
# L3 programming layer <2021-02-18>
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amscls/amsart.cls
# Document Class: amsart 2020/05/29 v2.20.6
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (I search kanjifont definition file: . . ) (I search font definition file: . .
# . . . . . ) (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsa.fd)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/amsfonts.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/geometry/geometry.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/generic/iftex/ifvtex.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/iftex/iftex.sty)))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/graphicx.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/graphics.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/trig.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-cfg/graphics.cfg)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-def/dvips.def)))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/amssymb.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/epstopdf-pkg/epstopdf.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/infwarerr/infwarerr.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/grfext/grfext.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/kvdefinekeys/kvdefinekeys.sty))
#  (/usr/local/texlive/2021/texmf-dist/tex/latex/kvoptions/kvoptions.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/ltxcmds/ltxcmds.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/generic/kvsetkeys/kvsetkeys.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/generic/pdftexcmds/pdftexcmds.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/epstopdf-pkg/epstopdf-base.sty
#
# Package epstopdf Warning: Drivers other than `pdftex' and `luatex' are not supp
# orted.
#
# )) (/usr/local/texlive/2021/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-cfg/color.cfg))
# (/usr/local/texlive/texmf-local/tex/latex/udline/udline.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/l3backend/l3backend-dvips.def)
# (new/data//001_005omitted.aux)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsa.fd)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsb.fd)
# *geometry* driver: auto-detecting
# *geometry* detected driver: dvips
# [1] (new/data//001_005omitted.aux) )
# Output written on new/data//001_005omitted.dvi (1 page, 2328 bytes).
# Transcript written on new/data//001_005omitted.log.
# new/data//001_005omitted.dvi -> new/data//001_005omitted.pdf
# [1]
# 26171 bytes written
# new/data//001_005omitted.pdf generated by dvipdfmx.
# This is ptex2pdf[.lua] version 20200520.0.
# Processing new/data/001_006full
# This is e-pTeX, Version 3.141592653-p3.9.0-210218-2.6 (utf8.euc) (TeX Live 2021) (preloaded format=platex)
#  restricted \write18 enabled.
# entering extended mode
# (./new/data/001_006full.tex
# pLaTeX2e <2020-10-01>+2 (based on LaTeX2e <2020-10-01> patch level 4)
# L3 programming layer <2021-02-18>
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amscls/amsart.cls
# Document Class: amsart 2020/05/29 v2.20.6
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (I search kanjifont definition file: . . ) (I search font definition file: . .
# . . . . . ) (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsa.fd)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/amsfonts.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/geometry/geometry.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/generic/iftex/ifvtex.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/iftex/iftex.sty)))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/graphicx.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/graphics.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/trig.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-cfg/graphics.cfg)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-def/dvips.def)))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/amssymb.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/epstopdf-pkg/epstopdf.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/infwarerr/infwarerr.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/grfext/grfext.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/kvdefinekeys/kvdefinekeys.sty))
#  (/usr/local/texlive/2021/texmf-dist/tex/latex/kvoptions/kvoptions.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/ltxcmds/ltxcmds.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/generic/kvsetkeys/kvsetkeys.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/generic/pdftexcmds/pdftexcmds.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/epstopdf-pkg/epstopdf-base.sty
#
# Package epstopdf Warning: Drivers other than `pdftex' and `luatex' are not supp
# orted.
#
# )) (/usr/local/texlive/2021/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-cfg/color.cfg))
# (/usr/local/texlive/texmf-local/tex/latex/udline/udline.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/l3backend/l3backend-dvips.def)
# (new/data//001_006full.aux)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsa.fd)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsb.fd)
# *geometry* driver: auto-detecting
# *geometry* detected driver: dvips
# [1] (new/data//001_006full.aux) )
# Output written on new/data//001_006full.dvi (1 page, 2632 bytes).
# Transcript written on new/data//001_006full.log.
# new/data//001_006full.dvi -> new/data//001_006full.pdf
# [1]
# 29042 bytes written
# new/data//001_006full.pdf generated by dvipdfmx.
# This is ptex2pdf[.lua] version 20200520.0.
# Processing new/data/001_006omitted
# This is e-pTeX, Version 3.141592653-p3.9.0-210218-2.6 (utf8.euc) (TeX Live 2021) (preloaded format=platex)
#  restricted \write18 enabled.
# entering extended mode
# (./new/data/001_006omitted.tex
# pLaTeX2e <2020-10-01>+2 (based on LaTeX2e <2020-10-01> patch level 4)
# L3 programming layer <2021-02-18>
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amscls/amsart.cls
# Document Class: amsart 2020/05/29 v2.20.6
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (I search kanjifont definition file: . . ) (I search font definition file: . .
# . . . . . ) (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsa.fd)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/amsfonts.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/geometry/geometry.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/generic/iftex/ifvtex.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/iftex/iftex.sty)))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/graphicx.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/graphics.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/trig.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-cfg/graphics.cfg)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-def/dvips.def)))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/amssymb.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/epstopdf-pkg/epstopdf.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/infwarerr/infwarerr.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/grfext/grfext.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/kvdefinekeys/kvdefinekeys.sty))
#  (/usr/local/texlive/2021/texmf-dist/tex/latex/kvoptions/kvoptions.sty
# ...
# 6  A: こんにちは！お元気でしたか？\n\nB: ああ、久しぶりです。こないだ成人しましたよ。...
# 7  A: 最悪ー！ちょっと聞いてよ、嫌なもの見ちゃった！\n\nB: どしたの？\n\nA: 中...
#
#                                        core_sentence condition  index  \
# 0               そうなんですね。お雛祭りの時だなんて、なんかいいですね。何より忘れない。      high    3.0
# 1                                            全然おっけー！       low    3.0
# 2                 いえいえ、それは大変でしたね。どうかあまり気を落とさないでください。       low    1.0
# 3      ほんと？そういわれると、自信がつく！わたし、無神論者だったけど、今はあなたが神に見えるよ！       low    4.0
# 4  東京は、飲み屋さんがいっぱいあるから、お酒が飲める人にとっては楽しいかもね。私はアルコールが...      high    4.0
# 5                             また紅葉の頃、お休みの日をお知らせしますね。      high    2.0
# 6                    オラオラ！８回生のお通りはい、道を開けんかい！　なんつってね。       low    2.0
# 7        うわ！それ、最悪だね！やっぱり、今回のDVDも罰ゲームみたいだと思う？これってイジメ？      high    1.0
#
#    similarity                                       full_summary  \
# 0    1.000000  B: 私はひな祭りの日に生まれたので、お雛祭りの時には特別な思いがあります。その瞬間を忘れる...
# 1    0.812182                               A: はい、名古屋めし食べるの、大歓迎！
# 2    0.793492  A: いえいえ、夫を亡くされたと聞いてとても心配です。どうか一人で悲しまずに、周りの人々の支...
# 3    0.841492  B: えー、太ってるのって、本人が気にするより、周りは誰も気にしてないものだよ。わたしみたい...
# 4    1.000000  東京にはたくさんの飲み屋があるので、お酒が好きな人にとっては楽しいかもしれません。私はアルコ...
# 5    1.000000                        B: 紅葉の季節になったら、私の休みの日を教えますね。
# 6    0.862845  B: ああ、私は大学の８回生なんですよ。まだまだ卒業まで時間がかかりそうですね。ただの冗談ですよ。
# 7    1.000000        うわ！それ、最悪だね！やっぱり、今回のDVDも罰ゲームみたいだと思う？これってイジメ？
#
#                                      omitted_summary
# 0  B: 私はひな祭りの日に生まれたので、お雛祭りの時には特別な思いがあります。その瞬間を忘れる...
# 1  「全然おっけー！」という発言は、AがBの提案に対して快諾していることを表しています。AはBの...
# 2  おっしゃる通り、ウニは高級な食材ですから、手に入れるのは大変だったでしょうね。でも、どうかお...
# 3   B: ほんと？そういわれると、自信がつく！わたし、無神論者だったけど、今はあなたが神に見えるよ！
# 4  東京にはたくさんの飲み屋があるので、お酒が好きな人にとっては楽しいかもしれません。私はアルコ...
# 5                        B: 紅葉の季節になったら、私の休みの日を教えますね。
# 6  Bは冗談を言っていて、自分が警察官であることを強調しています。彼は「オラオラ！８回生のお通り...
# 7        うわ！それ、最悪だね！やっぱり、今回のDVDも罰ゲームみたいだと思う？これってイジメ？
# This is ptex2pdf[.lua] version 20200520.0.
# Processing new/data/009_000full
# This is e-pTeX, Version 3.141592653-p3.9.0-210218-2.6 (utf8.euc) (TeX Live 2021) (preloaded format=platex)
#  restricted \write18 enabled.
# entering extended mode
# (./new/data/009_000full.tex
# pLaTeX2e <2020-10-01>+2 (based on LaTeX2e <2020-10-01> patch level 4)
# L3 programming layer <2021-02-18>
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amscls/amsart.cls
# Document Class: amsart 2020/05/29 v2.20.6
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (I search kanjifont definition file: . . ) (I search font definition file: . .
# . . . . . ) (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsa.fd)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/amsfonts.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/geometry/geometry.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/generic/iftex/ifvtex.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/iftex/iftex.sty)))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/graphicx.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/graphics.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/trig.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-cfg/graphics.cfg)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-def/dvips.def)))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/amssymb.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/epstopdf-pkg/epstopdf.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/infwarerr/infwarerr.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/grfext/grfext.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/kvdefinekeys/kvdefinekeys.sty))
#  (/usr/local/texlive/2021/texmf-dist/tex/latex/kvoptions/kvoptions.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/ltxcmds/ltxcmds.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/generic/kvsetkeys/kvsetkeys.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/generic/pdftexcmds/pdftexcmds.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/epstopdf-pkg/epstopdf-base.sty
#
# Package epstopdf Warning: Drivers other than `pdftex' and `luatex' are not supp
# orted.
#
# )) (/usr/local/texlive/2021/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-cfg/color.cfg))
# (/usr/local/texlive/texmf-local/tex/latex/udline/udline.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/l3backend/l3backend-dvips.def)
# (new/data//009_000full.aux)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsa.fd)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsb.fd)
# *geometry* driver: auto-detecting
# *geometry* detected driver: dvips
# [1] (new/data//009_000full.aux) )
# Output written on new/data//009_000full.dvi (1 page, 3120 bytes).
# Transcript written on new/data//009_000full.log.
# new/data//009_000full.dvi -> new/data//009_000full.pdf
# [1]
# 31034 bytes written
# new/data//009_000full.pdf generated by dvipdfmx.
# This is ptex2pdf[.lua] version 20200520.0.
# Processing new/data/009_000omitted
# This is e-pTeX, Version 3.141592653-p3.9.0-210218-2.6 (utf8.euc) (TeX Live 2021) (preloaded format=platex)
#  restricted \write18 enabled.
# entering extended mode
# (./new/data/009_000omitted.tex
# pLaTeX2e <2020-10-01>+2 (based on LaTeX2e <2020-10-01> patch level 4)
# L3 programming layer <2021-02-18>
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amscls/amsart.cls
# Document Class: amsart 2020/05/29 v2.20.6
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (I search kanjifont definition file: . . ) (I search font definition file: . .
# . . . . . ) (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsa.fd)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/amsfonts.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/geometry/geometry.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/generic/iftex/ifvtex.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/iftex/iftex.sty)))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/graphicx.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/graphics.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/trig.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-cfg/graphics.cfg)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-def/dvips.def)))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/amssymb.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/epstopdf-pkg/epstopdf.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/infwarerr/infwarerr.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/grfext/grfext.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/kvdefinekeys/kvdefinekeys.sty))
#  (/usr/local/texlive/2021/texmf-dist/tex/latex/kvoptions/kvoptions.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/ltxcmds/ltxcmds.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/generic/kvsetkeys/kvsetkeys.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/generic/pdftexcmds/pdftexcmds.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/epstopdf-pkg/epstopdf-base.sty
#
# Package epstopdf Warning: Drivers other than `pdftex' and `luatex' are not supp
# orted.
#
# )) (/usr/local/texlive/2021/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-cfg/color.cfg))
# (/usr/local/texlive/texmf-local/tex/latex/udline/udline.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/l3backend/l3backend-dvips.def)
# (new/data//009_000omitted.aux)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsa.fd)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsb.fd)
# *geometry* driver: auto-detecting
# *geometry* detected driver: dvips
# [1] (new/data//009_000omitted.aux) )
# Output written on new/data//009_000omitted.dvi (1 page, 2896 bytes).
# Transcript written on new/data//009_000omitted.log.
# new/data//009_000omitted.dvi -> new/data//009_000omitted.pdf
# [1]
# 29128 bytes written
# new/data//009_000omitted.pdf generated by dvipdfmx.
# This is ptex2pdf[.lua] version 20200520.0.
# Processing new/data/009_001full
# This is e-pTeX, Version 3.141592653-p3.9.0-210218-2.6 (utf8.euc) (TeX Live 2021) (preloaded format=platex)
#  restricted \write18 enabled.
# entering extended mode
# (./new/data/009_001full.tex
# pLaTeX2e <2020-10-01>+2 (based on LaTeX2e <2020-10-01> patch level 4)
# L3 programming layer <2021-02-18>
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amscls/amsart.cls
# Document Class: amsart 2020/05/29 v2.20.6
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (I search kanjifont definition file: . . ) (I search font definition file: . .
# . . . . . ) (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsa.fd)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/amsfonts.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/geometry/geometry.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/generic/iftex/ifvtex.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/iftex/iftex.sty)))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/graphicx.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/graphics.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/trig.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-cfg/graphics.cfg)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-def/dvips.def)))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/amssymb.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/epstopdf-pkg/epstopdf.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/infwarerr/infwarerr.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/grfext/grfext.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/kvdefinekeys/kvdefinekeys.sty))
#  (/usr/local/texlive/2021/texmf-dist/tex/latex/kvoptions/kvoptions.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/ltxcmds/ltxcmds.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/generic/kvsetkeys/kvsetkeys.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/generic/pdftexcmds/pdftexcmds.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/epstopdf-pkg/epstopdf-base.sty
#
# Package epstopdf Warning: Drivers other than `pdftex' and `luatex' are not supp
# orted.
#
# )) (/usr/local/texlive/2021/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-cfg/color.cfg))
# (/usr/local/texlive/texmf-local/tex/latex/udline/udline.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/l3backend/l3backend-dvips.def)
# (new/data//009_001full.aux)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsa.fd)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsb.fd)
# *geometry* driver: auto-detecting
# *geometry* detected driver: dvips
# [1] (new/data//009_001full.aux) )
# Output written on new/data//009_001full.dvi (1 page, 2752 bytes).
# Transcript written on new/data//009_001full.log.
# new/data//009_001full.dvi -> new/data//009_001full.pdf
# [1]
# 27775 bytes written
# new/data//009_001full.pdf generated by dvipdfmx.
# This is ptex2pdf[.lua] version 20200520.0.
# Processing new/data/009_001omitted
# This is e-pTeX, Version 3.141592653-p3.9.0-210218-2.6 (utf8.euc) (TeX Live 2021) (preloaded format=platex)
#  restricted \write18 enabled.
# entering extended mode
# (./new/data/009_001omitted.tex
# pLaTeX2e <2020-10-01>+2 (based on LaTeX2e <2020-10-01> patch level 4)
# L3 programming layer <2021-02-18>
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amscls/amsart.cls
# Document Class: amsart 2020/05/29 v2.20.6
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (I search kanjifont definition file: . . ) (I search font definition file: . .
# . . . . . ) (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsa.fd)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/amsfonts.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/geometry/geometry.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/generic/iftex/ifvtex.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/iftex/iftex.sty)))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/graphicx.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/graphics.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics/trig.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-cfg/graphics.cfg)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-def/dvips.def)))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/amssymb.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/epstopdf-pkg/epstopdf.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/infwarerr/infwarerr.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/grfext/grfext.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/kvdefinekeys/kvdefinekeys.sty))
#  (/usr/local/texlive/2021/texmf-dist/tex/latex/kvoptions/kvoptions.sty
# (/usr/local/texlive/2021/texmf-dist/tex/generic/ltxcmds/ltxcmds.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/generic/kvsetkeys/kvsetkeys.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/generic/pdftexcmds/pdftexcmds.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/epstopdf-pkg/epstopdf-base.sty
#
# Package epstopdf Warning: Drivers other than `pdftex' and `luatex' are not supp
# orted.
#
# )) (/usr/local/texlive/2021/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/graphics-cfg/color.cfg))
# (/usr/local/texlive/texmf-local/tex/latex/udline/udline.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/l3backend/l3backend-dvips.def)
# (new/data//009_001omitted.aux)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsa.fd)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsfonts/umsb.fd)
# *geometry* driver: auto-detecting
# *geometry* detected driver: dvips
# [1] (new/data//009_001omitted.aux) )
# Output written on new/data//009_001omitted.dvi (1 page, 2368 bytes).
# Transcript written on new/data//009_001omitted.log.
# new/data//009_001omitted.dvi -> new/data//009_001omitted.pdf
# [1]
# 26311 bytes written
# new/data//009_001omitted.pdf generated by dvipdfmx.
# This is ptex2pdf[.lua] version 20200520.0.
# Processing new/data/009_002full
# This is e-pTeX, Version 3.141592653-p3.9.0-210218-2.6 (utf8.euc) (TeX Live 2021) (preloaded format=platex)
#  restricted \write18 enabled.
# entering extended mode
# (./new/data/009_002full.tex
# pLaTeX2e <2020-10-01>+2 (based on LaTeX2e <2020-10-01> patch level 4)
# L3 programming layer <2021-02-18>
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amscls/amsart.cls
# Document Class: amsart 2020/05/29 v2.20.6
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/local/texlive/2021/texmf-dist/tex/latex/amsmath/amsopn.sty)

# %%
# # Load importance data
# import os
# import pandas as pd

# importance_data = pd.DataFrame()
# print(importance_data)
# importance_path = "./results/generations/distant/"
# importance_file_list = os.listdir(importance_path)
# for filename in importance_file_list:
#     df = pd.read_csv(importance_path + filename, names = ["filename", "first", "second"])
#     importance_data = pd.concat([importance_data, df])

# # Cast dtype
# importance_data = importance_data.astype({"first": int, "second": int})

# # Remove duplicates
# # importance_data = importance_data.drop_duplicates(subset=["filename"], keep="last")

# importance_data.info()

# %%
# # Combine similarity and importance
# combined_data = pd.DataFrame(
#     columns=["filename", "turn", "utterance", "low_similarity", "important"]
# )

# n_dialogue = 100
# threshold = 0.85

# for idx_dialogue in range(1, n_dialogue + 1):
#     filename = "PP" + str(idx_dialogue) + ".txt"
#     with open("./dat/" + filename) as f:
#         dialogue = [l.rstrip() for l in f.readlines()]

#     importance_row = importance_data.query(
#         "filename == @filename"
#     )

#     for idx_utterance, utterance in enumerate(dialogue):
#         summary_row = results.query(
#             "filename == @filename and (turn == @idx_utterance + 1 or turn == @idx_utterance + 2)"
#         )
#         if len(summary_row.query("similarity < @threshold")) > 0:
#             int_low_similarity = 1
#         else:
#             int_low_similarity = 0

#         if len(importance_row.query(
#             "first == @idx_utterance + 1 or second == @idx_utterance + 1"
#         )) > 0:
#             int_important = 1
#         else:
#             int_important = 0

#         new_data = pd.DataFrame({
#             "filename": [filename],
#             "turn": [idx_utterance + 1],
#             "utterance": [utterance],
#             "low_similarity": [int_low_similarity],
#             "important": [int_important]
#         })
#         combined_data = pd.concat([combined_data, new_data])

# print(combined_data)

# %%
# # Save as CSV
# for dialogue_idx in range(1, n_dialogue + 1):
#     dialogue_filename = "PP" + str(dialogue_idx) + ".txt"
#     sample_data = combined_data.query("filename == @dialogue_filename")
#     csv_filename = "./tmp/combined" + str(dialogue_idx) + ".csv"
#     sample_data.to_csv(csv_filename)

# %%
# # Show cross table
# crossed = pd.crosstab(combined_data["low_similarity"], combined_data["important"])
# print(crossed)

# %%
# # Chi-square test
# import scipy as sp
# import scipy.stats

# chi2_stats = sp.stats.chi2_contingency(crossed)
# print(chi2_stats)

# %%
# # List important SCAINs
# important_scain = combined_data.query("low_similarity == 1 and important ==1")
# print(important_scain)
